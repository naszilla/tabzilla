# %%
import pandas as pd

# %%
df = pd.read_csv("./neural_non_neural_comparison.csv")
df.head()
# Out:
#                                  dataset_fold_id  Accuracy__test_neural  \
# 0  openml__Amazon_employee_access__34539__fold_0               0.945072
# 1  openml__Amazon_employee_access__34539__fold_1               0.951175
# 2  openml__Amazon_employee_access__34539__fold_2               0.946292
# 3  openml__Amazon_employee_access__34539__fold_3               0.946597
# 4  openml__Amazon_employee_access__34539__fold_4               0.957583
#
#    Accuracy__test_non-neural  F1__test_neural  F1__test_non-neural  \
# 0                   0.945682         0.945072             0.945682
# 1                   0.951175         0.951175             0.951175
# 2                   0.948123         0.946292             0.948123
# 3                   0.949954         0.946597             0.949954
# 4                   0.955447         0.957583             0.955447
#
#    MSE__test_neural  MSE__test_non-neural  Log Loss__test_neural  \
# 0               NaN                   NaN               0.161965
# 1               NaN                   NaN               0.159829
# 2               NaN                   NaN               0.168089
# 3               NaN                   NaN               0.163559
# 4               NaN                   NaN               0.142165
#
#    Log Loss__test_non-neural alg_name_neural alg_name_non-neural  \
# 0                   0.154921           SAINT            CatBoost
# 1                   0.154622           SAINT            LightGBM
# 2                   0.154905           SAINT            LightGBM
# 3                   0.158825           SAINT            LightGBM
# 4                   0.146234           SAINT            LightGBM
#
#    time__train_neural  time__train_non-neural  time__test_neural  \
# 0          121.021030                1.854008           0.144149
# 1          121.650418                4.938074           0.150993
# 2           88.650241                4.015220           0.130198
# 3          127.776521                4.456510           0.159156
# 4           93.065000                3.046130           0.140077
#
#    time__test_non-neural
# 0               0.041222
# 1               0.221166
# 2               0.118386
# 3               0.143771
# 4               0.066967

# %% [markdown]
# ## Analyze difference between neural/non-neural algs

# %%
# calculate difference between nerual/non-neural performance for eahn metric
metric_list = ["Accuracy__test", "F1__test", "MSE__test", "Log Loss__test", "time__train", "time__test"]

for metric in metric_list:
    df.loc[:, f"{metric}_diff"] = df[f"{metric}_neural"] - df[f"{metric}_non-neural"]

# include dataset name as well
df.loc[:, "dataset_name"] = df["dataset_fold_id"].apply(lambda x: x[:-len("__fold_1")])

# %%
# for how many datasets do neural methods win?
print("number of dataset splits where neural methods achieve higher (better) F1 score :")
print((df["F1__test_diff"] > 0).value_counts())

print("number of dataset splits where neural methods achieve lower (better) log loss :")
print((df["Log Loss__test_diff"] < 0).value_counts())
# Out:
# number of dataset splits where neural methods achieve higher (better) F1 score :
# False    975
# True     335
# Name: F1__test_diff, dtype: int64
# number of dataset splits where neural methods achieve lower (better) log loss :
# False    891
# True     419
# Name: Log Loss__test_diff, dtype: int64

# %% [markdown]
# So, neural networks win on roughly 25% of all datasets.

# %%
# which algorithms win - from both neural and non-neural?
print("most-winning neural algs:")
print(df["alg_name_neural"].value_counts())

print("most-winning non-neural algs:")
print(df["alg_name_non-neural"].value_counts())
# Out:
# most-winning neural algs:
# TabNet                564
# DANet                 181
# SAINT                 148
# TabTransformer         84
# rtdl_FTTransformer     69
# rtdl_ResNet            68
# MLP                    61
# rtdl_MLP               47
# NODE                   37
# STG                    35
# VIME                    9
# DeepFM                  6
# NAM                     1
# Name: alg_name_neural, dtype: int64
# most-winning non-neural algs:
# CatBoost        331
# LightGBM        328
# XGBoost         201
# SVM             154
# DecisionTree    139
# RandomForest     71
# KNN              55
# LinearModel      31
# Name: alg_name_non-neural, dtype: int64

# %% [markdown]
# The neural methods are largely dominated by TabNet, while various tree methods perform well for non-neural.

# %% [markdown]
# ## Assess dataset metafeatures

# %%
# read & merge in meta-features
metafeatures_df = pd.read_csv("../TabSurvey/metafeatures.csv")
print(metafeatures_df.head())
# Out:
#                  dataset_name  f__pymfe.landmarking.best_node.count  \
# 0  openml__cjs__14967__fold_0                                    10
# 1  openml__cjs__14967__fold_1                                    10
# 2  openml__cjs__14967__fold_2                                    10
# 3  openml__cjs__14967__fold_3                                    10
# 4  openml__cjs__14967__fold_4                                    10
#
#    f__pymfe.landmarking.best_node.count.relative  \
# 0                                            4.0
# 1                                            4.0
# 2                                            4.0
# 3                                            4.0
# 4                                            4.0
#
#    f__pymfe.landmarking.best_node.histogram.0  \
# 0                                         0.3
# 1                                         0.1
# 2                                         0.3
# 3                                         0.1
# 4                                         0.1
#
#    f__pymfe.landmarking.best_node.histogram.0.relative  \
# 0                                                6.5
# 1                                                4.0
# 2                                                7.0
# 3                                                3.5
# 4                                                3.5
#
#    f__pymfe.landmarking.best_node.histogram.1  \
# 0                                         0.0
# 1                                         0.0
# 2                                         0.1
# 3                                         0.1
# 4                                         0.1
#
#    f__pymfe.landmarking.best_node.histogram.1.relative  \
# 0                                                2.5
# 1                                                3.0
# 2                                                5.5
# 3                                                4.5
# 4                                                6.5
#
#    f__pymfe.landmarking.best_node.histogram.2  \
# 0                                         0.2
# 1                                         0.0
# 2                                         0.1
# 3                                         0.1
# 4                                         0.1
#
#    f__pymfe.landmarking.best_node.histogram.2.relative  \
# 0                                                6.5
# 1                                                2.5
# 2                                                4.5
# 3                                                6.0
# 4                                                5.5
#
#    f__pymfe.landmarking.best_node.histogram.3  ...  \
# 0                                         0.2  ...
# 1                                         0.2  ...
# 2                                         0.0  ...
# 3                                         0.3  ...
# 4                                         0.4  ...
#
#    f__pymfe.relative.worst_node.quantiles.4  \
# 0                                  0.166667
# 1                                  0.171573
# 2                                  0.166667
# 3                                  0.166667
# 4                                  0.171970
#
#    f__pymfe.relative.worst_node.quantiles.4.relative  \
# 0                                                1.0
# 1                                                1.0
# 2                                                1.0
# 3                                                1.0
# 4                                                1.0
#
#    f__pymfe.relative.worst_node.range  \
# 0                            0.000000
# 1                            0.007937
# 2                            0.000000
# 3                            0.000000
# 4                            0.010497
#
#    f__pymfe.relative.worst_node.range.relative  \
# 0                                          1.0
# 1                                          1.0
# 2                                          1.0
# 3                                          1.0
# 4                                          1.0
#
#    f__pymfe.relative.worst_node.sd  f__pymfe.relative.worst_node.sd.relative  \
# 0                     2.925695e-17                                       1.0
# 1                     1.912000e-03                                       1.0
# 2                     2.925695e-17                                       1.0
# 3                     2.925695e-17                                       1.0
# 4                     2.801491e-03                                       1.0
#
#    f__pymfe.relative.worst_node.skewness  \
# 0                                    NaN
# 1                               1.025611
# 2                                    NaN
# 3                                    NaN
# 4                              -0.045710
#
#    f__pymfe.relative.worst_node.skewness.relative  \
# 0                                             7.0
# 1                                             7.0
# 2                                             7.0
# 3                                             7.0
# 4                                             5.0
#
#    f__pymfe.statistical.iq_range  f__pymfe.statistical.t_mean
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# 2                            NaN                          NaN
# 3                            NaN                          NaN
# 4                            NaN                          NaN
#
# [5 rows x 1605 columns]

# %%
merged_df = df.merge(metafeatures_df, left_on="dataset_fold_id", right_on="dataset_name", how="left")

# %%
merged_df
# Out:
#                                     dataset_fold_id  Accuracy__test_neural  \
# 0     openml__Amazon_employee_access__34539__fold_0               0.945072
# 1     openml__Amazon_employee_access__34539__fold_1               0.951175
# 2     openml__Amazon_employee_access__34539__fold_2               0.946292
# 3     openml__Amazon_employee_access__34539__fold_3               0.946597
# 4     openml__Amazon_employee_access__34539__fold_4               0.957583
# ...                                             ...                    ...
# 1305                  openml__yeast__145793__fold_5               0.653543
# 1306                  openml__yeast__145793__fold_6               0.614173
# 1307                  openml__yeast__145793__fold_7               0.637795
# 1308                  openml__yeast__145793__fold_8               0.622047
# 1309                  openml__yeast__145793__fold_9               0.658730
#
#       Accuracy__test_non-neural  F1__test_neural  F1__test_non-neural  \
# 0                      0.945682         0.945072             0.945682
# 1                      0.951175         0.951175             0.951175
# 2                      0.948123         0.946292             0.948123
# 3                      0.949954         0.946597             0.949954
# 4                      0.955447         0.957583             0.955447
# ...                         ...              ...                  ...
# 1305                   0.669291         0.651901             0.672491
# 1306                   0.669291         0.613821             0.669725
# 1307                   0.685039         0.632844             0.678220
# 1308                   0.677165         0.620988             0.672749
# 1309                   0.658730         0.656046             0.656970
#
#       MSE__test_neural  MSE__test_non-neural  Log Loss__test_neural  \
# 0                  NaN                   NaN               0.161965
# 1                  NaN                   NaN               0.159829
# 2                  NaN                   NaN               0.168089
# 3                  NaN                   NaN               0.163559
# 4                  NaN                   NaN               0.142165
# ...                ...                   ...                    ...
# 1305               NaN                   NaN               0.856060
# 1306               NaN                   NaN               1.062902
# 1307               NaN                   NaN               0.983789
# 1308               NaN                   NaN               0.967557
# 1309               NaN                   NaN               0.886908
#
#       Log Loss__test_non-neural alg_name_neural  ...  \
# 0                      0.154921           SAINT  ...
# 1                      0.154622           SAINT  ...
# 2                      0.154905           SAINT  ...
# 3                      0.158825           SAINT  ...
# 4                      0.146234           SAINT  ...
# ...                         ...             ...  ...
# 1305                   0.772932          TabNet  ...
# 1306                   0.822254          TabNet  ...
# 1307                   0.854731             STG  ...
# 1308                   0.879122          TabNet  ...
# 1309                   0.808102          TabNet  ...
#
#      f__pymfe.relative.worst_node.quantiles.4  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ...                                       ...
# 1305                                     0.25
# 1306                                     0.25
# 1307                                     0.25
# 1308                                     0.25
# 1309                                     0.25
#
#       f__pymfe.relative.worst_node.quantiles.4.relative  \
# 0                                                   7.0
# 1                                                   7.0
# 2                                                   7.0
# 3                                                   7.0
# 4                                                   7.0
# ...                                                 ...
# 1305                                                1.5
# 1306                                                1.5
# 1307                                                1.5
# 1308                                                1.5
# 1309                                                1.5
#
#       f__pymfe.relative.worst_node.range  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# ...                                  ...
# 1305                            0.014286
# 1306                            0.007143
# 1307                            0.007143
# 1308                            0.007143
# 1309                            0.000000
#
#       f__pymfe.relative.worst_node.range.relative  \
# 0                                             7.0
# 1                                             7.0
# 2                                             7.0
# 3                                             7.0
# 4                                             7.0
# ...                                           ...
# 1305                                          1.5
# 1306                                          1.5
# 1307                                          2.0
# 1308                                          2.0
# 1309                                          1.5
#
#       f__pymfe.relative.worst_node.sd  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# ...                               ...
# 1305                         0.004821
# 1306                         0.003012
# 1307                         0.002259
# 1308                         0.002259
# 1309                         0.000000
#
#       f__pymfe.relative.worst_node.sd.relative  \
# 0                                          7.0
# 1                                          7.0
# 2                                          7.0
# 3                                          7.0
# 4                                          7.0
# ...                                        ...
# 1305                                       2.0
# 1306                                       2.0
# 1307                                       2.0
# 1308                                       2.0
# 1309                                       1.5
#
#       f__pymfe.relative.worst_node.skewness  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 1305                              -1.639149
# 1306                              -1.280722
# 1307                              -2.276840
# 1308                              -2.276840
# 1309                                    NaN
#
#       f__pymfe.relative.worst_node.skewness.relative  \
# 0                                                7.0
# 1                                                7.0
# 2                                                7.0
# 3                                                7.0
# 4                                                7.0
# ...                                              ...
# 1305                                             2.0
# 1306                                             3.0
# 1307                                             2.0
# 1308                                             1.0
# 1309                                             7.0
#
#       f__pymfe.statistical.iq_range  f__pymfe.statistical.t_mean
# 0                               NaN                          NaN
# 1                               NaN                          NaN
# 2                               NaN                          NaN
# 3                               NaN                          NaN
# 4                               NaN                          NaN
# ...                             ...                          ...
# 1305                            NaN                          NaN
# 1306                            NaN                          NaN
# 1307                            NaN                          NaN
# 1308                            NaN                          NaN
# 1309                            NaN                          NaN
#
# [1310 rows x 1627 columns]

# %%
# correlation between Log Loss difference and each meta-feature.

metafeature_cols = metafeatures_df.columns[1:]

metric_col = "Log Loss__test_diff"

corrs = []
for col in metafeature_cols:
    corrs.append(merged_df[metric_col].corr(merged_df[col]))

corr_df = pd.DataFrame(
    {
        "metafeature": metafeature_cols,
        f"corr_with_{metric_col}": corrs,
    }
)

corr_df.loc[:, "abs_corr"] = corr_df[f"corr_with_{metric_col}"].abs()

# %%
print(corr_df.sort_values(f"abs_corr", ascending=False).head(50))
# Out:
#                                            metafeature  \
# 44                f__pymfe.landmarking.best_node.range
# 1296                 f__pymfe.relative.best_node.range
# 46                   f__pymfe.landmarking.best_node.sd
# 1298                    f__pymfe.relative.best_node.sd
# 1596                f__pymfe.relative.worst_node.range
# 344              f__pymfe.landmarking.worst_node.range
# 96                    f__pymfe.landmarking.elite_nn.sd
# 1348                     f__pymfe.relative.elite_nn.sd
# 1346                  f__pymfe.relative.elite_nn.range
# 94                 f__pymfe.landmarking.elite_nn.range
# 1548                  f__pymfe.relative.random_node.sd
# 296                f__pymfe.landmarking.random_node.sd
# 196                f__pymfe.landmarking.naive_bayes.sd
# 1448                  f__pymfe.relative.naive_bayes.sd
# 294             f__pymfe.landmarking.random_node.range
# 1546               f__pymfe.relative.random_node.range
# 1498                       f__pymfe.relative.one_nn.sd
# 246                     f__pymfe.landmarking.one_nn.sd
# 1598                   f__pymfe.relative.worst_node.sd
# 346                 f__pymfe.landmarking.worst_node.sd
# 194             f__pymfe.landmarking.naive_bayes.range
# 1446               f__pymfe.relative.naive_bayes.range
# 1398                 f__pymfe.relative.linear_discr.sd
# 146               f__pymfe.landmarking.linear_discr.sd
# 1094       f__pymfe.model-based.tree_shape.quantiles.3
# 1474                 f__pymfe.relative.one_nn.iq_range
# 222               f__pymfe.landmarking.one_nn.iq_range
# 172          f__pymfe.landmarking.naive_bayes.iq_range
# 1424            f__pymfe.relative.naive_bayes.iq_range
# 1089            f__pymfe.model-based.tree_shape.median
# 1093       f__pymfe.model-based.tree_shape.quantiles.2
# 350                      f__pymfe.general.attr_to_inst
# 144            f__pymfe.landmarking.linear_discr.range
# 1396              f__pymfe.relative.linear_discr.range
# 1088              f__pymfe.model-based.tree_shape.mean
# 22             f__pymfe.landmarking.best_node.iq_range
# 1274              f__pymfe.relative.best_node.iq_range
# 1496                    f__pymfe.relative.one_nn.range
# 244                  f__pymfe.landmarking.one_nn.range
# 919              f__pymfe.model-based.leaves_corrob.sd
# 72              f__pymfe.landmarking.elite_nn.iq_range
# 1324               f__pymfe.relative.elite_nn.iq_range
# 1092       f__pymfe.model-based.tree_shape.quantiles.1
# 1374           f__pymfe.relative.linear_discr.iq_range
# 122         f__pymfe.landmarking.linear_discr.iq_range
# 984   f__pymfe.model-based.nodes_per_level.histogram.9
# 1085          f__pymfe.model-based.tree_shape.iq_range
# 272          f__pymfe.landmarking.random_node.iq_range
# 1524            f__pymfe.relative.random_node.iq_range
# 1084       f__pymfe.model-based.tree_shape.histogram.9
#
#       corr_with_Log Loss__test_diff  abs_corr
# 44                         0.357317  0.357317
# 1296                       0.357317  0.357317
# 46                         0.353595  0.353595
# 1298                       0.353595  0.353595
# 1596                       0.336163  0.336163
# 344                        0.336163  0.336163
# 96                         0.334436  0.334436
# 1348                       0.334436  0.334436
# 1346                       0.332711  0.332711
# 94                         0.332711  0.332711
# 1548                       0.321478  0.321478
# 296                        0.321478  0.321478
# 196                        0.312402  0.312402
# 1448                       0.312402  0.312402
# 294                        0.311273  0.311273
# 1546                       0.311273  0.311273
# 1498                       0.304912  0.304912
# 246                        0.304912  0.304912
# 1598                       0.302792  0.302792
# 346                        0.302792  0.302792
# 194                        0.302451  0.302451
# 1446                       0.302451  0.302451
# 1398                       0.295631  0.295631
# 146                        0.295631  0.295631
# 1094                       0.282207  0.282207
# 1474                       0.277372  0.277372
# 222                        0.277372  0.277372
# 172                        0.276105  0.276105
# 1424                       0.276105  0.276105
# 1089                       0.275690  0.275690
# 1093                       0.275690  0.275690
# 350                        0.274988  0.274988
# 144                        0.272208  0.272208
# 1396                       0.272208  0.272208
# 1088                       0.269991  0.269991
# 22                         0.267347  0.267347
# 1274                       0.267347  0.267347
# 1496                       0.264740  0.264740
# 244                        0.264740  0.264740
# 919                        0.255734  0.255734
# 72                         0.248091  0.248091
# 1324                       0.248091  0.248091
# 1092                       0.240860  0.240860
# 1374                       0.237527  0.237527
# 122                        0.237527  0.237527
# 984                        0.222004  0.222004
# 1085                       0.219387  0.219387
# 272                        0.210919  0.210919
# 1524                       0.210919  0.210919
# 1084                       0.199539  0.199539

# %% [markdown]
# Interesting that all entries with the largest correlations have positive correlations. Also, most of these are lanmarking-based metafeatures.
#
# For reference, we are correlating two numbers:
# - metafeatures (e.g., performance of a landmarking method)
# - difference between performance of (neural - non-neural) metric. For log-loss, lower values are better, so **positive values mean that the non-neural method performs better than the neural method.
#
# high correlation here means: higher values of the metafeature <==> non-neural method performs better.
