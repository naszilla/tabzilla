# %%
# get tuned alg results for each split separately

import pandas as pd
import numpy as np

metadataset_df = pd.read_csv("./results/tuned_fold_results.csv")

# %% [markdown]
# # Develop outcome measures for each dataset split

# %%
# categorize each alg

neural_algs = [
    "MLP",
    "TabNet",
    "VIME",
    "TabTransformer",
    "NODE",
    "STG",
    "NAM",
    "DeepFM",
    "SAINT",
    "DANet",
    "rtdl_MLP",
    "rtdl_ResNet",
    "rtdl_FTTransformer",
    "TabPFNModel"
]

tree_algs = [
    "LightGBM",
    "XGBoost",
    "CatBoost",
    "RandomForest",

]

baseline_algs = [
    "DecisionTree",
    "LinearModel",
    "KNN",
    "SVM",
]

metadataset_df.loc[:, "alg_type"] = "baseline"
metadataset_df.loc[metadataset_df["alg_name"].isin(neural_algs), "alg_type"] = "neural"
metadataset_df.loc[metadataset_df["alg_name"].isin(tree_algs), "alg_type"] = "trees"

print(metadataset_df.groupby("alg_type")["alg_name"].value_counts())
# Out:
# alg_type  alg_name
# baseline  DecisionTree          1710
#           LinearModel           1670
#           KNN                   1640
#           SVM                   1430
# neural    rtdl_MLP              1710
#           MLP                   1700
#           rtdl_ResNet           1700
#           TabNet                1660
#           STG                   1630
#           VIME                  1620
#           DANet                 1470
#           rtdl_FTTransformer    1390
#           NODE                  1380
#           TabTransformer        1220
#           SAINT                 1060
#           DeepFM                 900
#           NAM                    800
#           TabPFNModel            630
# trees     XGBoost               1710
#           RandomForest          1700
#           LightGBM              1640
#           CatBoost              1630
# Name: alg_name, dtype: int64

# %% [markdown]
# ## Clean metafeatures
# - remove feats with nan
# - remove redundant features (those with eqaul values for all datasets)

# %%
from metadata_utils import process_metafeatures

metafeatures_df = pd.read_csv("../TabSurvey/metafeatures.csv")
metafeatures_processed = process_metafeatures(metafeatures_df, filter_families=None)
# Out:
# /Users/duncan/research/active_projects/tabzilla/tabzilla_analysis/metadata_utils.py:56: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   metafeatures_processed = metafeatures_df.fillna(metafeatures_df.median())

# %%
def cor(x, y):
    return np.corrcoef(x, y)[0, 1]

# %%
all_feature_cols = [c for c in metafeatures_df.columns if c.startswith("f__")]

# no_nan_metafeatures = metafeatures_df[all_feature_cols].isna().sum() == 0
# print(f"number of metafeatures with no nans: {sum(no_nan_metafeatures)}")
# print(f"number of metafeatures with nans:    {sum(~no_nan_metafeatures)}")

# get features with no NaNs
# no_nan_feats = list(no_nan_metafeatures[no_nan_metafeatures].index)

# find and remove/record redundant features
redundant_feats = []
for i, feat in enumerate(all_feature_cols):
    if feat in redundant_feats:
        continue
    for j in range(i + 1, len(all_feature_cols)):
        if (metafeatures_processed[feat] == metafeatures_processed[all_feature_cols[j]]).all():
            print(f"removing feat: {all_feature_cols[j]} (equal to {feat}")
            redundant_feats.append(all_feature_cols[j])
        elif cor(metafeatures_processed[feat].values, metafeatures_processed[all_feature_cols[j]].values) > 0.999:
            print(f"removing feat: {all_feature_cols[j]} (corr with {feat}")
            redundant_feats.append(all_feature_cols[j])

redundant_feats = list(set(redundant_feats))

print(f"removing {len(redundant_feats)} redundant features:")
# for f in redundant_feats: print(f)

# keep only features which have no NaNs and are not redundant
keep_feats = [f for f in all_feature_cols if f not in redundant_feats]

# final dataset
keep_metafeatures_df = metafeatures_processed.loc[:, ["dataset_name"] + keep_feats]

keep_metafeatures_df.loc[:, "dataset_family"] = keep_metafeatures_df["dataset_name"].apply(lambda x: x[:-len("__fold_x")])

# %%
# save this as "cleaned" metafeatures
keep_metafeatures_df.to_csv("./results/cleaned_metafeatures.csv", index="dataset_name")

# %%
################
# IF CLEANED METAFEATURES HAS ALREADY BEEN WRITTEN
keep_metafeatures_df = pd.read_csv("./results/cleaned_metafeatures.csv", index_col=0)

# drop cols that are all NaN

# keep_metafeatures_df.loc[keep_metafeatures_df.isna().sum() > 0, :]
na_feats = keep_metafeatures_df.isna().sum() == len(keep_metafeatures_df)
na_feat_names = list(na_feats[na_feats].index)
print(f"dropping cols with only NA: {na_feat_names}")
keep_metafeatures_df.drop(columns=na_feat_names, inplace=True)

# replace inf with something else
keep_metafeatures_df.replace([np.inf, -np.inf], 0.0, inplace=True)


# # scale the data...
# from sklearn.preprocessing import RobustScaler
# feature_cols = [c for c in keep_metafeatures_df.columns if c.startswith("f__pymfe")]
# robust_scaler = RobustScaler().fit(keep_metafeatures_df[feature_cols])
# keep_metafeatures_df.loc[:, feature_cols] = robust_scaler.transform(keep_metafeatures_df[feature_cols])
# Out:
# dropping cols with only NA: ['f__pymfe.statistical.iq_range', 'f__pymfe.statistical.t_mean']

# %%
keep_metafeatures_df.head()
# Out:
#                  dataset_name  f__pymfe.landmarking.best_node.count  \
# 0  openml__cjs__14967__fold_0                                    10
# 1  openml__cjs__14967__fold_1                                    10
# 2  openml__cjs__14967__fold_2                                    10
# 3  openml__cjs__14967__fold_3                                    10
# 4  openml__cjs__14967__fold_4                                    10
#
#    f__pymfe.landmarking.best_node.count.relative  \
# 0                                            4.0
# 1                                            4.0
# 2                                            4.0
# 3                                            4.0
# 4                                            4.0
#
#    f__pymfe.landmarking.best_node.histogram.0  \
# 0                                         0.3
# 1                                         0.1
# 2                                         0.3
# 3                                         0.1
# 4                                         0.1
#
#    f__pymfe.landmarking.best_node.histogram.0.relative  \
# 0                                                6.5
# 1                                                4.0
# 2                                                7.0
# 3                                                3.5
# 4                                                3.5
#
#    f__pymfe.landmarking.best_node.histogram.1  \
# 0                                         0.0
# 1                                         0.0
# 2                                         0.1
# 3                                         0.1
# 4                                         0.1
#
#    f__pymfe.landmarking.best_node.histogram.1.relative  \
# 0                                                2.5
# 1                                                3.0
# 2                                                5.5
# 3                                                4.5
# 4                                                6.5
#
#    f__pymfe.landmarking.best_node.histogram.2  \
# 0                                         0.2
# 1                                         0.0
# 2                                         0.1
# 3                                         0.1
# 4                                         0.1
#
#    f__pymfe.landmarking.best_node.histogram.2.relative  \
# 0                                                6.5
# 1                                                2.5
# 2                                                4.5
# 3                                                6.0
# 4                                                5.5
#
#    f__pymfe.landmarking.best_node.histogram.3  ...  \
# 0                                         0.2  ...
# 1                                         0.2  ...
# 2                                         0.0  ...
# 3                                         0.3  ...
# 4                                         0.4  ...
#
#    f__pymfe.info-theory.mut_inf.mean  f__pymfe.info-theory.mut_inf.median  \
# 0                           1.292908                             1.292908
# 1                           1.291474                             1.291474
# 2                           1.296524                             1.296524
# 3                           1.299327                             1.299327
# 4                           1.294577                             1.294577
#
#    f__pymfe.info-theory.mut_inf.min  f__pymfe.info-theory.mut_inf.quantiles.1  \
# 0                          0.065752                                  0.679330
# 1                          0.062884                                  0.677179
# 2                          0.072983                                  0.684753
# 3                          0.078187                                  0.688757
# 4                          0.068546                                  0.681562
#
#    f__pymfe.info-theory.mut_inf.quantiles.3  \
# 0                                  1.906486
# 1                                  1.905769
# 2                                  1.908294
# 3                                  1.909898
# 4                                  1.907592
#
#    f__pymfe.info-theory.mut_inf.range  f__pymfe.info-theory.mut_inf.sd  \
# 0                            2.454313                         1.735461
# 1                            2.457180                         1.737489
# 2                            2.447082                         1.730348
# 3                            2.442282                         1.726954
# 4                            2.452061                         1.733869
#
#    f__pymfe.info-theory.mut_inf.skewness  f__pymfe.info-theory.ns_ratio  \
# 0                                    0.0                       2.325505
# 1                                    0.0                       2.336153
# 2                                    0.0                       2.327456
# 3                                    0.0                       2.313806
# 4                                    0.0                       2.322964
#
#        dataset_family
# 0  openml__cjs__14967
# 1  openml__cjs__14967
# 2  openml__cjs__14967
# 3  openml__cjs__14967
# 4  openml__cjs__14967
#
# [5 rows x 967 columns]

# %% [markdown]
# ## merge performance dataset with metafeatures

# %%
# get best-performing alg type for each dataset split
best_alg_df_dict = {}
neural_tree_diff_dict = {}

metric_list = [
    "Accuracy",
    "F1",
    "Log Loss",
]

obj_type_list = [
    "max",
    "max",
    "min",
]

for metric, obj_type in zip(metric_list, obj_type_list):

    ####################################################################################
    # get the difference in metric between the best neural and tree alg for each dataset
    if obj_type == "max":
        tree_best = metadataset_df[metadataset_df["alg_type"] == "trees"].groupby("dataset_fold_id")[f"normalized_{metric}__test"] \
            .max().reset_index()
        neural_best = metadataset_df[metadataset_df["alg_type"] == "neural"].groupby("dataset_fold_id")[f"normalized_{metric}__test"] \
            .max().reset_index()
    elif obj_type == "min":
        tree_best = metadataset_df[metadataset_df["alg_type"] == "trees"].groupby("dataset_fold_id")[f"normalized_{metric}__test"] \
            .min().reset_index()
        neural_best = metadataset_df[metadataset_df["alg_type"] == "neural"].groupby("dataset_fold_id")[f"normalized_{metric}__test"] \
            .min().reset_index()

    # merge these and get the difference & abs-difference
    neural_tree_diff = neural_best.merge(tree_best, on="dataset_fold_id", suffixes=["_neural", "_trees"], how="inner")

    neural_tree_diff.loc[:, "neural_tree_diff"] = neural_tree_diff[f"normalized_{metric}__test_neural"] - neural_tree_diff[f"normalized_{metric}__test_trees"]
    neural_tree_diff.loc[:, "abs_neural_tree_diff"] = neural_tree_diff.loc[:, "neural_tree_diff"].abs()

    neural_tree_diff_dict[metric] = neural_tree_diff

    #################################
    # # define the "top-ranked" algs

    # df_metric = metadataset_df.loc[metadataset_df[f"{metric}_rank"] == 1, :]
    df_metric = metadataset_df.loc[metadataset_df[f"normalized_{metric}__test"] >= 0.95, :]

    # get best performance for each alg type
    df_best_performance = metadataset_df.groupby(["dataset_fold_id", "alg_type"])[f"normalized_{metric}__test"].max().rename(f"best_{metric}").reset_index()

    # get a list of all top-ranked algs for each dataset split
    best_algs = df_metric.groupby("dataset_fold_id")["alg_type"].apply(lambda x: set(x)).reset_index()
    

    # add a binary col indicating whether best alg includes each alg class
    for alg_type in ["trees", "neural", "baseline"]:
        # print(alg_type)
        # print(best_algs.head())
        best_algs.loc[:, f"{alg_type}_win"] = best_algs["alg_type"].apply(lambda x: 1 if alg_type in x else 0)

        # add the best performance for the alg type
        best_perf = df_best_performance.loc[df_best_performance["alg_type"] == alg_type, ["dataset_fold_id", f"best_{metric}"]].copy()
        best_perf.rename(columns={f"best_{metric}": f"best_{metric}_{alg_type}"}, inplace=True)
        best_algs = best_algs.merge(best_perf, on="dataset_fold_id", how="left")

    best_alg_df_dict[metric] = best_algs

# %%
# len(best_alg_df_dict["Accuracy"]["dataset_fold_id"].unique()) # 1705
set(metadataset_df["dataset_fold_id"].unique()).difference(best_alg_df_dict["Accuracy"]["dataset_fold_id"].unique())

# which folds are missing?
# Out:
# {'openml__postoperative-patient-data__146210__fold_7',
#  'openml__rabe_266__3647__fold_7',
#  'openml__solar-flare__2068__fold_0',
#  'openml__solar-flare__2068__fold_1',
#  'openml__solar-flare__2068__fold_8'}

# %%
# there are errors with these splits.

# %%
# merge on dataset split name
for metric in metric_list:
    neural_tree_diff_dict[metric] = neural_tree_diff_dict[metric].merge(keep_metafeatures_df, left_on="dataset_fold_id", right_on="dataset_name", how="left")
    best_alg_df_dict[metric] = best_alg_df_dict[metric].merge(keep_metafeatures_df, left_on="dataset_fold_id", right_on="dataset_name", how="left")

# %%
best_alg_df_dict["Accuracy"].head(40)
# Out:
#                                   dataset_fold_id                   alg_type  \
# 0              openml__APSFailure__168868__fold_0                    {trees}
# 1              openml__APSFailure__168868__fold_1                    {trees}
# 2              openml__APSFailure__168868__fold_2                    {trees}
# 3              openml__APSFailure__168868__fold_3                    {trees}
# 4              openml__APSFailure__168868__fold_4                    {trees}
# 5              openml__APSFailure__168868__fold_5  {neural, trees, baseline}
# 6              openml__APSFailure__168868__fold_6                    {trees}
# 7              openml__APSFailure__168868__fold_7                    {trees}
# 8              openml__APSFailure__168868__fold_8                    {trees}
# 9              openml__APSFailure__168868__fold_9                    {trees}
# 10  openml__Amazon_employee_access__34539__fold_0                    {trees}
# 11  openml__Amazon_employee_access__34539__fold_1            {neural, trees}
# 12  openml__Amazon_employee_access__34539__fold_2                    {trees}
# 13  openml__Amazon_employee_access__34539__fold_3                    {trees}
# 14  openml__Amazon_employee_access__34539__fold_4            {neural, trees}
# 15  openml__Amazon_employee_access__34539__fold_5                   {neural}
# 16  openml__Amazon_employee_access__34539__fold_6            {neural, trees}
# 17  openml__Amazon_employee_access__34539__fold_7                    {trees}
# 18  openml__Amazon_employee_access__34539__fold_8                    {trees}
# 19  openml__Amazon_employee_access__34539__fold_9                    {trees}
# 20             openml__Australian__146818__fold_0                   {neural}
# 21             openml__Australian__146818__fold_1                    {trees}
# 22             openml__Australian__146818__fold_2                   {neural}
# 23             openml__Australian__146818__fold_3                   {neural}
# 24             openml__Australian__146818__fold_4                   {neural}
# 25             openml__Australian__146818__fold_5                    {trees}
# 26             openml__Australian__146818__fold_6                   {neural}
# 27             openml__Australian__146818__fold_7                   {neural}
# 28             openml__Australian__146818__fold_8  {neural, trees, baseline}
# 29             openml__Australian__146818__fold_9                    {trees}
# 30              openml__Bioresponse__9910__fold_0                    {trees}
# 31              openml__Bioresponse__9910__fold_1            {neural, trees}
# 32              openml__Bioresponse__9910__fold_2            {neural, trees}
# 33              openml__Bioresponse__9910__fold_3                    {trees}
# 34              openml__Bioresponse__9910__fold_4                    {trees}
# 35              openml__Bioresponse__9910__fold_5                    {trees}
# 36              openml__Bioresponse__9910__fold_6                    {trees}
# 37              openml__Bioresponse__9910__fold_7                 {baseline}
# 38              openml__Bioresponse__9910__fold_8                    {trees}
# 39              openml__Bioresponse__9910__fold_9                    {trees}
#
#     trees_win  best_Accuracy_trees  neural_win  best_Accuracy_neural  \
# 0           1             1.000000           0              0.931373
# 1           1             1.000000           0              0.770115
# 2           1             1.000000           0              0.912088
# 3           1             1.000000           0              0.944444
# 4           1             1.000000           0              0.857143
# 5           1             1.000000           1              0.985348
# 6           1             1.000000           0              0.901961
# 7           1             1.000000           0              0.947791
# 8           1             1.000000           0              0.747475
# 9           1             1.000000           0              0.772277
# 10          1             1.000000           0              0.906250
# 11          1             0.972603           1              1.000000
# 12          1             1.000000           0              0.844444
# 13          1             1.000000           0              0.948718
# 14          1             1.000000           1              0.961905
# 15          0             0.932203           1              1.000000
# 16          1             0.972222           1              1.000000
# 17          1             1.000000           0              0.843137
# 18          1             1.000000           0              0.805970
# 19          1             1.000000           0              0.828571
# 20          0             0.888889           1              1.000000
# 21          1             1.000000           0              0.950000
# 22          0             0.900000           1              1.000000
# 23          0             0.818182           1              1.000000
# 24          0             0.941176           1              1.000000
# 25          1             1.000000           0              0.888889
# 26          0             0.846154           1              1.000000
# 27          0             0.944444           1              1.000000
# 28          1             1.000000           1              1.000000
# 29          1             1.000000           0              0.928571
# 30          1             1.000000           0              0.743590
# 31          1             0.972973           1              1.000000
# 32          1             1.000000           1              1.000000
# 33          1             1.000000           0              0.933333
# 34          1             1.000000           0              0.593750
# 35          1             1.000000           0              0.666667
# 36          1             1.000000           0              0.500000
# 37          0             0.942857           0              0.742857
# 38          1             1.000000           0              0.642857
# 39          1             1.000000           0              0.818182
#
#     baseline_win  best_Accuracy_baseline  \
# 0              0                0.715686
# 1              0                0.712644
# 2              0                0.659341
# 3              0                0.878307
# 4              0                0.647619
# 5              1                0.959707
# 6              0                0.725490
# 7              0                0.903614
# 8              0                0.656566
# 9              0                0.742574
# 10             0                0.343750
# 11             0                0.561644
# 12             0                0.488889
# 13             0                0.769231
# 14             0                0.590476
# 15             0                0.661017
# 16             0                0.666667
# 17             0                0.568627
# 18             0                0.492537
# 19             0                0.385714
# 20             0                0.611111
# 21             0                0.900000
# 22             0                0.500000
# 23             0                0.545455
# 24             0                0.941176
# 25             0                0.833333
# 26             0                0.846154
# 27             0                0.888889
# 28             1                1.000000
# 29             0                0.785714
# 30             0                0.564103
# 31             0                0.648649
# 32             0                0.851852
# 33             0                0.866667
# 34             0                0.781250
# 35             0                0.666667
# 36             0                0.923077
# 37             1                1.000000
# 38             0                0.857143
# 39             0                0.575758
#
#                                      dataset_name  \
# 0              openml__APSFailure__168868__fold_0
# 1              openml__APSFailure__168868__fold_1
# 2              openml__APSFailure__168868__fold_2
# 3              openml__APSFailure__168868__fold_3
# 4              openml__APSFailure__168868__fold_4
# 5              openml__APSFailure__168868__fold_5
# 6              openml__APSFailure__168868__fold_6
# 7              openml__APSFailure__168868__fold_7
# 8              openml__APSFailure__168868__fold_8
# 9              openml__APSFailure__168868__fold_9
# 10  openml__Amazon_employee_access__34539__fold_0
# 11  openml__Amazon_employee_access__34539__fold_1
# 12  openml__Amazon_employee_access__34539__fold_2
# 13  openml__Amazon_employee_access__34539__fold_3
# 14  openml__Amazon_employee_access__34539__fold_4
# 15  openml__Amazon_employee_access__34539__fold_5
# 16  openml__Amazon_employee_access__34539__fold_6
# 17  openml__Amazon_employee_access__34539__fold_7
# 18  openml__Amazon_employee_access__34539__fold_8
# 19  openml__Amazon_employee_access__34539__fold_9
# 20             openml__Australian__146818__fold_0
# 21             openml__Australian__146818__fold_1
# 22             openml__Australian__146818__fold_2
# 23             openml__Australian__146818__fold_3
# 24             openml__Australian__146818__fold_4
# 25             openml__Australian__146818__fold_5
# 26             openml__Australian__146818__fold_6
# 27             openml__Australian__146818__fold_7
# 28             openml__Australian__146818__fold_8
# 29             openml__Australian__146818__fold_9
# 30              openml__Bioresponse__9910__fold_0
# 31              openml__Bioresponse__9910__fold_1
# 32              openml__Bioresponse__9910__fold_2
# 33              openml__Bioresponse__9910__fold_3
# 34              openml__Bioresponse__9910__fold_4
# 35              openml__Bioresponse__9910__fold_5
# 36              openml__Bioresponse__9910__fold_6
# 37              openml__Bioresponse__9910__fold_7
# 38              openml__Bioresponse__9910__fold_8
# 39              openml__Bioresponse__9910__fold_9
#
#     f__pymfe.landmarking.best_node.count  ...  \
# 0                                     10  ...
# 1                                     10  ...
# 2                                     10  ...
# 3                                     10  ...
# 4                                     10  ...
# 5                                     10  ...
# 6                                     10  ...
# 7                                     10  ...
# 8                                     10  ...
# 9                                     10  ...
# 10                                     0  ...
# 11                                     0  ...
# 12                                     0  ...
# 13                                     0  ...
# 14                                     0  ...
# 15                                     0  ...
# 16                                     0  ...
# 17                                     0  ...
# 18                                     0  ...
# 19                                     0  ...
# 20                                    10  ...
# 21                                    10  ...
# 22                                    10  ...
# 23                                    10  ...
# 24                                    10  ...
# 25                                    10  ...
# 26                                    10  ...
# 27                                    10  ...
# 28                                    10  ...
# 29                                    10  ...
# 30                                    10  ...
# 31                                    10  ...
# 32                                    10  ...
# 33                                    10  ...
# 34                                    10  ...
# 35                                    10  ...
# 36                                    10  ...
# 37                                    10  ...
# 38                                    10  ...
# 39                                    10  ...
#
#     f__pymfe.info-theory.mut_inf.mean  f__pymfe.info-theory.mut_inf.median  \
# 0                            0.057252                             0.034458
# 1                            0.057252                             0.034458
# 2                            0.057252                             0.034458
# 3                            0.057252                             0.034458
# 4                            0.057252                             0.034458
# 5                            0.057252                             0.034458
# 6                            0.057252                             0.034458
# 7                            0.057252                             0.034458
# 8                            0.057252                             0.034458
# 9                            0.057252                             0.034458
# 10                           0.057953                             0.028352
# 11                           0.058609                             0.029369
# 12                           0.058404                             0.029231
# 13                           0.057675                             0.028164
# 14                           0.057898                             0.029291
# 15                           0.058532                             0.030513
# 16                           0.057596                             0.029052
# 17                           0.056861                             0.028162
# 18                           0.056778                             0.028244
# 19                           0.057288                             0.028391
# 20                           0.098573                             0.039035
# 21                           0.098937                             0.044049
# 22                           0.102856                             0.046957
# 23                           0.101124                             0.043272
# 24                           0.094045                             0.038777
# 25                           0.096749                             0.041457
# 26                           0.102316                             0.050259
# 27                           0.098518                             0.040871
# 28                           0.096011                             0.030583
# 29                           0.098021                             0.034463
# 30                           0.057252                             0.034458
# 31                           0.057252                             0.034458
# 32                           0.057252                             0.034458
# 33                           0.057252                             0.034458
# 34                           0.057252                             0.034458
# 35                           0.057252                             0.034458
# 36                           0.057252                             0.034458
# 37                           0.057252                             0.034458
# 38                           0.057252                             0.034458
# 39                           0.057252                             0.034458
#
#     f__pymfe.info-theory.mut_inf.min  \
# 0                           0.002171
# 1                           0.002171
# 2                           0.002171
# 3                           0.002171
# 4                           0.002171
# 5                           0.002171
# 6                           0.002171
# 7                           0.002171
# 8                           0.002171
# 9                           0.002171
# 10                          0.011506
# 11                          0.011881
# 12                          0.012212
# 13                          0.011659
# 14                          0.012095
# 15                          0.012693
# 16                          0.011677
# 17                          0.011289
# 18                          0.011145
# 19                          0.011204
# 20                          0.000020
# 21                          0.000113
# 22                          0.000065
# 23                          0.001026
# 24                          0.003000
# 25                          0.000077
# 26                          0.000027
# 27                          0.000258
# 28                          0.000142
# 29                          0.000140
# 30                          0.002171
# 31                          0.002171
# 32                          0.002171
# 33                          0.002171
# 34                          0.002171
# 35                          0.002171
# 36                          0.002171
# 37                          0.002171
# 38                          0.002171
# 39                          0.002171
#
#     f__pymfe.info-theory.mut_inf.quantiles.1  \
# 0                                   0.015280
# 1                                   0.015280
# 2                                   0.015280
# 3                                   0.015280
# 4                                   0.015280
# 5                                   0.015280
# 6                                   0.015280
# 7                                   0.015280
# 8                                   0.015280
# 9                                   0.015280
# 10                                  0.021604
# 11                                  0.021429
# 12                                  0.021149
# 13                                  0.021281
# 14                                  0.022198
# 15                                  0.021768
# 16                                  0.019517
# 17                                  0.019378
# 18                                  0.019507
# 19                                  0.020202
# 20                                  0.008313
# 21                                  0.006965
# 22                                  0.003991
# 23                                  0.008954
# 24                                  0.008605
# 25                                  0.004406
# 26                                  0.008730
# 27                                  0.010217
# 28                                  0.010155
# 29                                  0.010329
# 30                                  0.015280
# 31                                  0.015280
# 32                                  0.015280
# 33                                  0.015280
# 34                                  0.015280
# 35                                  0.015280
# 36                                  0.015280
# 37                                  0.015280
# 38                                  0.015280
# 39                                  0.015280
#
#     f__pymfe.info-theory.mut_inf.quantiles.3  \
# 0                                   0.069672
# 1                                   0.069672
# 2                                   0.069672
# 3                                   0.069672
# 4                                   0.069672
# 5                                   0.069672
# 6                                   0.069672
# 7                                   0.069672
# 8                                   0.069672
# 9                                   0.069672
# 10                                  0.076698
# 11                                  0.078790
# 12                                  0.077837
# 13                                  0.076660
# 14                                  0.077521
# 15                                  0.077856
# 16                                  0.078109
# 17                                  0.077125
# 18                                  0.076672
# 19                                  0.077233
# 20                                  0.127244
# 21                                  0.114228
# 22                                  0.122517
# 23                                  0.133803
# 24                                  0.123051
# 25                                  0.116286
# 26                                  0.124928
# 27                                  0.130427
# 28                                  0.122953
# 29                                  0.125462
# 30                                  0.069672
# 31                                  0.069672
# 32                                  0.069672
# 33                                  0.069672
# 34                                  0.069672
# 35                                  0.069672
# 36                                  0.069672
# 37                                  0.069672
# 38                                  0.069672
# 39                                  0.069672
#
#     f__pymfe.info-theory.mut_inf.range  f__pymfe.info-theory.mut_inf.sd  \
# 0                             0.197973                         0.062782
# 1                             0.197973                         0.062782
# 2                             0.197973                         0.062782
# 3                             0.197973                         0.062782
# 4                             0.197973                         0.062782
# 5                             0.197973                         0.062782
# 6                             0.197973                         0.062782
# 7                             0.197973                         0.062782
# 8                             0.197973                         0.062782
# 9                             0.197973                         0.062782
# 10                            0.143702                         0.054049
# 11                            0.144741                         0.054320
# 12                            0.143834                         0.054219
# 13                            0.140898                         0.053720
# 14                            0.140167                         0.053258
# 15                            0.140894                         0.053617
# 16                            0.142696                         0.054015
# 17                            0.142248                         0.053808
# 18                            0.141218                         0.053553
# 19                            0.142847                         0.053693
# 20                            0.421635                         0.143052
# 21                            0.431873                         0.146075
# 22                            0.454296                         0.153201
# 23                            0.424666                         0.143378
# 24                            0.391684                         0.132816
# 25                            0.427947                         0.144274
# 26                            0.434498                         0.145549
# 27                            0.402866                         0.137217
# 28                            0.425495                         0.144506
# 29                            0.440863                         0.148500
# 30                            0.197973                         0.062782
# 31                            0.197973                         0.062782
# 32                            0.197973                         0.062782
# 33                            0.197973                         0.062782
# 34                            0.197973                         0.062782
# 35                            0.197973                         0.062782
# 36                            0.197973                         0.062782
# 37                            0.197973                         0.062782
# 38                            0.197973                         0.062782
# 39                            0.197973                         0.062782
#
#     f__pymfe.info-theory.mut_inf.skewness  f__pymfe.info-theory.ns_ratio  \
# 0                                0.751749                      18.249693
# 1                                0.751749                      18.249693
# 2                                0.751749                      18.249693
# 3                                0.751749                      18.249693
# 4                                0.751749                      18.249693
# 5                                0.751749                      18.249693
# 6                                0.751749                      18.249693
# 7                                0.751749                      18.249693
# 8                                0.751749                      18.249693
# 9                                0.751749                      18.249693
# 10                               0.812611                     117.845081
# 11                               0.801062                     116.638110
# 12                               0.797701                     117.071658
# 13                               0.793661                     118.564013
# 14                               0.798079                     118.141047
# 15                               0.795525                     116.719472
# 16                               0.785732                     118.643628
# 17                               0.796248                     120.252886
# 18                               0.794516                     120.365625
# 19                               0.796081                     119.223392
# 20                               1.319696                      12.340309
# 21                               1.369569                      12.300849
# 22                               1.391776                      11.716140
# 23                               1.324966                      11.931757
# 24                               1.329474                      12.960704
# 25                               1.400474                      12.588572
# 26                               1.363768                      11.828098
# 27                               1.246281                      12.202032
# 28                               1.372082                      12.506657
# 29                               1.427159                      12.313517
# 30                               0.751749                      18.249693
# 31                               0.751749                      18.249693
# 32                               0.751749                      18.249693
# 33                               0.751749                      18.249693
# 34                               0.751749                      18.249693
# 35                               0.751749                      18.249693
# 36                               0.751749                      18.249693
# 37                               0.751749                      18.249693
# 38                               0.751749                      18.249693
# 39                               0.751749                      18.249693
#
#                            dataset_family
# 0              openml__APSFailure__168868
# 1              openml__APSFailure__168868
# 2              openml__APSFailure__168868
# 3              openml__APSFailure__168868
# 4              openml__APSFailure__168868
# 5              openml__APSFailure__168868
# 6              openml__APSFailure__168868
# 7              openml__APSFailure__168868
# 8              openml__APSFailure__168868
# 9              openml__APSFailure__168868
# 10  openml__Amazon_employee_access__34539
# 11  openml__Amazon_employee_access__34539
# 12  openml__Amazon_employee_access__34539
# 13  openml__Amazon_employee_access__34539
# 14  openml__Amazon_employee_access__34539
# 15  openml__Amazon_employee_access__34539
# 16  openml__Amazon_employee_access__34539
# 17  openml__Amazon_employee_access__34539
# 18  openml__Amazon_employee_access__34539
# 19  openml__Amazon_employee_access__34539
# 20             openml__Australian__146818
# 21             openml__Australian__146818
# 22             openml__Australian__146818
# 23             openml__Australian__146818
# 24             openml__Australian__146818
# 25             openml__Australian__146818
# 26             openml__Australian__146818
# 27             openml__Australian__146818
# 28             openml__Australian__146818
# 29             openml__Australian__146818
# 30              openml__Bioresponse__9910
# 31              openml__Bioresponse__9910
# 32              openml__Bioresponse__9910
# 33              openml__Bioresponse__9910
# 34              openml__Bioresponse__9910
# 35              openml__Bioresponse__9910
# 36              openml__Bioresponse__9910
# 37              openml__Bioresponse__9910
# 38              openml__Bioresponse__9910
# 39              openml__Bioresponse__9910
#
# [40 rows x 975 columns]

# %% [markdown]
# # Q2: Can we predict when baselines will perform well, regardless of whether other alg classes perform well.

# %%
def cor(x, y):
    return np.corrcoef(x, y)[0, 1]

# %%
# find correlation between each feature and baseline performance

metric = "Accuracy"
target_col = f"best_{metric}_baseline"
df = best_alg_df_dict[metric]


feature_cols = [c for c in df.columns if c.startswith("f__pymfe")]
nice_feature_names = [f[len("f__pymfe."):] for f in feature_cols]


corrs = [cor(df[f], df[target_col]) for f in feature_cols]

print("highest-correlated features with baseline performance:")
abs_coef = np.abs(corrs)

idx_sorted_q2 = (-abs_coef).argsort()

num_print_feats = 30

for i in range(num_print_feats):
    print(f"{i + 1}: {nice_feature_names[idx_sorted_q2[i]]}: {abs_coef[idx_sorted_q2[i]]}")

q1a_keep_idx = idx_sorted_q2[:30]
# Out:
# highest-correlated features with baseline performance:
# 1: landmarking.linear_discr.max: 0.36512926038262783
# 2: landmarking.linear_discr.quantiles.3: 0.3629998499627998
# 3: statistical.can_cor.max: 0.3537273915090953
# 4: landmarking.naive_bayes.quantiles.3: 0.35295881907104193
# 5: landmarking.naive_bayes.median: 0.3493016030062868
# 6: landmarking.linear_discr.mean: 0.3471195797303933
# 7: landmarking.naive_bayes.max: 0.3471141343214779
# 8: landmarking.linear_discr.median: 0.3470671965543688
# 9: statistical.can_cor.quantiles.3: 0.34639174057343014
# 10: landmarking.naive_bayes.mean: 0.34534734130714584
# 11: landmarking.one_nn.max: 0.34137400858300193
# 12: model-based.leaves_homo.skewness: 0.3336284703978503
# 13: landmarking.naive_bayes.quantiles.1: 0.32733656900337255
# 14: landmarking.linear_discr.quantiles.1: 0.3254297180784973
# 15: statistical.can_cor.median: 0.3230369291694794
# 16: model-based.leaves_branch.min: 0.32245455425525693
# 17: statistical.can_cor.mean: 0.3204122199901499
# 18: statistical.w_lambda: 0.3152824039149852
# 19: landmarking.one_nn.quantiles.3: 0.3149989625803122
# 20: model-based.tree_shape.max: 0.294298192033202
# 21: landmarking.one_nn.mean: 0.29156792873900966
# 22: landmarking.one_nn.median: 0.28674622691384494
# 23: model-based.nodes_per_level.quantiles.1: 0.27851103547081046
# 24: landmarking.linear_discr.min: 0.2740902895239911
# 25: model-based.tree_shape.histogram.0: 0.2715190537235336
# 26: landmarking.naive_bayes.min: 0.26803656119568764
# 27: landmarking.one_nn.quantiles.1: 0.2656815059865139
# 28: model-based.leaves_corrob.skewness: 0.2605316328253256
# 29: statistical.can_cor.quantiles.1: 0.2596519244657646
# 30: model-based.tree_shape.range: 0.2577934548021644

# %%
## plot diff abs diff with feature, for all datasets
import matplotlib.pyplot as plt

fig, axs = plt.subplots(1, 6, figsize=(15, 3))

for i in range(6):
    plot_feat = feature_cols[idx_sorted_q2[i]]
    feat_name = nice_feature_names[idx_sorted_q2[i]]

    print(f"plotting feature {plot_feat} (corr with baseline performance = {cor(df[plot_feat], df[target_col])}")

    axs[i].scatter(df[plot_feat], df[target_col], s=3)

    axs[i].set_xlabel(feat_name)
    # ax.legend()
    # ax.set_xlabel(feat_comparison[0])
    # ax.set_ylabel(feat_comparison[1])

    # ax.set_yscale("log")
    axs[i].set_xscale("log")

axs[0].set_ylabel(f"Baseline {metric}")

plt.tight_layout()
# Out:
# plotting feature f__pymfe.landmarking.linear_discr.max (corr with baseline performance = 0.36512926038262783
# plotting feature f__pymfe.landmarking.linear_discr.quantiles.3 (corr with baseline performance = 0.3629998499627998
# plotting feature f__pymfe.statistical.can_cor.max (corr with baseline performance = 0.3537273915090953
# plotting feature f__pymfe.landmarking.naive_bayes.quantiles.3 (corr with baseline performance = 0.35295881907104193
# plotting feature f__pymfe.landmarking.naive_bayes.median (corr with baseline performance = 0.3493016030062868
# plotting feature f__pymfe.landmarking.linear_discr.mean (corr with baseline performance = 0.3471195797303933

# %%
## plot diff abs diff with feature, for all datasets
import matplotlib.pyplot as plt

offset = 6
fig, axs = plt.subplots(1, 6, figsize=(15, 3))

for i in range(6):
    plot_feat = feature_cols[idx_sorted_q2[i + offset]]
    feat_name = nice_feature_names[idx_sorted_q2[i + offset]]

    print(f"plotting feature {plot_feat} (corr with baseline performance = {cor(df[plot_feat], df[target_col])}")

    axs[i].scatter(df[plot_feat], df[target_col], s=3)

    axs[i].set_xlabel(feat_name)
    # ax.legend()
    # ax.set_xlabel(feat_comparison[0])
    # ax.set_ylabel(feat_comparison[1])

    # ax.set_yscale("log")
    # axs[i].set_xscale("log")

axs[0].set_ylabel(f"Baseline {metric}")

plt.tight_layout()
# Out:
# plotting feature f__pymfe.landmarking.naive_bayes.max (corr with baseline performance = 0.3471141343214779
# plotting feature f__pymfe.landmarking.linear_discr.median (corr with baseline performance = 0.3470671965543688
# plotting feature f__pymfe.statistical.can_cor.quantiles.3 (corr with baseline performance = 0.34639174057343014
# plotting feature f__pymfe.landmarking.naive_bayes.mean (corr with baseline performance = 0.34534734130714584
# plotting feature f__pymfe.landmarking.one_nn.max (corr with baseline performance = 0.34137400858300193
# plotting feature f__pymfe.model-based.leaves_homo.skewness (corr with baseline performance = -0.3336284703978503

# %% [markdown]
# ### now try lasso

# %%
from sklearn.linear_model import LassoCV
from sklearn.linear_model import LogisticRegression

lasso_q1 = LassoCV(cv=5, random_state=0, verbose=True, max_iter=5000).fit(df[feature_cols].clip(-1e10, 1e10), df[target_col])

print("lasso-identified features:")
abs_coef = np.abs(lasso_q1.coef_)

idx_sorted_lasso = (-abs_coef).argsort()
# threshold = importance[idx_third] + 0.01

num_print_feats = 15

for i in range(num_print_feats):
    print(f"{nice_feature_names[idx_sorted_lasso[i]]}: {abs_coef[idx_sorted_lasso[i]]}")
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................[Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    1.0s finished
# lasso-identified features:
# statistical.cov.median: 1.6286229363575648e-10
# statistical.eigenvalues.median: 3.977092786332873e-11
# statistical.eigenvalues.quantiles.1: 2.9093632530319924e-11
# model-based.leaves_homo.quantiles.1: 2.3997542885883792e-11
# statistical.gravity: 2.3599949063706547e-11
# model-based.leaves_homo.max: 1.456264443126079e-11
# model-based.leaves_homo.median: 1.3159689201315532e-11
# model-based.leaves_homo.iq_range: 1.1854221813742e-11
# statistical.cov.iq_range: 1.1040544892726558e-11
# statistical.cov.quantiles.1: 1.0632407744304717e-12
# statistical.h_mean.max: 2.1889867391334872e-13
# statistical.min.max: 1.4611997204956916e-13
# landmarking.best_node.count: 0.0
# statistical.t_mean.quantiles.3: 0.0
# statistical.t_mean.kurtosis: 0.0

# %% [markdown]
# ### train tree ensemble

# %%
# from xgboost import XGBClassifier, XGBRegressor
# from sklearn import metrics 

# x = df[feature_cols].clip(-1e10, 1e10)
# y = df["baseline_win"]

# # xgb_q1 = XGBRegressor(n_estimators=150, max_depth=5, early_stopping_rounds=5, use_label_encoder=False).fit(x, y)
# xgb_q1 = XGBClassifier(n_estimators=50, max_depth=5, early_stopping_rounds=5, use_label_encoder=False).fit(x, y)

# print("xgb features with high importance:")


# abs_coef = xgb_q1.feature_importances_

# idx_sorted_xgb = (-abs_coef).argsort()

# num_print_feats = 20

# for i in range(num_print_feats):
#     print(f"{nice_feature_names[idx_sorted_xgb[i]]}: {abs_coef[idx_sorted_xgb[i]]}")

# q1c_keep_idx = idx_sorted_xgb[:30]

# print(metrics.classification_report(y, xgb_q1.predict(x)))
# print("confusion matrix:")
# print(metrics.confusion_matrix(y, xgb_q1.predict(x)))

# %% [markdown]
# ### find a small decision tree and check overall accuracy

# %%
from sklearn import tree 
from sklearn import metrics

x = df[feature_cols].clip(-1e10, 1e10)
y = df["baseline_win"]

print(f"num instances: {len(y)}")
print(f"num positive (y=1): {y.sum()}")
print(f"num negative (y=0): {len(y) - y.sum()}")


# clf = tree.DecisionTreeClassifier(max_depth=2).fit(x, y)
clf = tree.DecisionTreeClassifier().fit(x, y)


print(metrics.classification_report(y, clf.predict(x)))
print("confusion matrix:")
print(metrics.confusion_matrix(y, clf.predict(x)))
# Out:
# num instances: 1705
# num positive (y=1): 679
# num negative (y=0): 1026
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1026
#            1       1.00      1.00      1.00       679
#
#     accuracy                           1.00      1705
#    macro avg       1.00      1.00      1.00      1705
# weighted avg       1.00      1.00      1.00      1705
#
# confusion matrix:
# [[1026    0]
#  [   1  678]]

# %%
tree.plot_tree(clf, feature_names=feature_cols)
# Out:
# [Text(0.4554812719898358, 0.9848484848484849, 'f__pymfe.landmarking.random_node.range <= 0.008\ngini = 0.479\nsamples = 1705\nvalue = [1026, 679]'),
#  Text(0.12440138780297107, 0.9545454545454546, 'f__pymfe.model-based.tree_imbalance.sd <= 0.066\ngini = 0.332\nsamples = 524\nvalue = [414, 110]'),
#  Text(0.06098514464425332, 0.9242424242424242, 'f__pymfe.statistical.mad.iq_range <= 0.004\ngini = 0.123\nsamples = 244\nvalue = [228, 16]'),
#  Text(0.04534792806880375, 0.8939393939393939, 'f__pymfe.landmarking.worst_node.histogram.3 <= 0.55\ngini = 0.298\nsamples = 44\nvalue = [36, 8]'),
#  Text(0.04222048475371384, 0.8636363636363636, 'f__pymfe.landmarking.linear_discr.histogram.5.relative <= 6.25\ngini = 0.273\nsamples = 43\nvalue = [36, 7]'),
#  Text(0.039093041438623924, 0.8333333333333334, 'f__pymfe.landmarking.worst_node.histogram.8 <= 0.05\ngini = 0.214\nsamples = 41\nvalue = [36, 5]'),
#  Text(0.03596559812353401, 0.803030303030303, 'f__pymfe.statistical.kurtosis.histogram.7 <= 0.001\ngini = 0.239\nsamples = 36\nvalue = [31, 5]'),
#  Text(0.0328381548084441, 0.7727272727272727, 'f__pymfe.statistical.sd.histogram.1 <= 0.194\ngini = 0.257\nsamples = 33\nvalue = [28, 5]'),
#  Text(0.0218921032056294, 0.7424242424242424, 'f__pymfe.landmarking.linear_discr.histogram.5 <= 0.25\ngini = 0.198\nsamples = 27\nvalue = [24, 3]'),
#  Text(0.01563721657544957, 0.7121212121212122, 'f__pymfe.statistical.median.histogram.0 <= 0.167\ngini = 0.159\nsamples = 23\nvalue = [21, 2]'),
#  Text(0.012509773260359656, 0.6818181818181818, 'f__pymfe.model-based.var_importance.histogram.3 <= 0.007\ngini = 0.375\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.009382329945269743, 0.6515151515151515, 'f__pymfe.landmarking.worst_node.histogram.6 <= 0.05\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.006254886630179828, 0.6212121212121212, 'f__pymfe.landmarking.elite_nn.quantiles.1 <= 0.14\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.003127443315089914, 0.5909090909090909, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.009382329945269743, 0.5909090909090909, 'f__pymfe.statistical.mean.histogram.8 <= 0.001\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.006254886630179828, 0.5606060606060606, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.012509773260359656, 0.5606060606060606, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.012509773260359656, 0.6212121212121212, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.01563721657544957, 0.6515151515151515, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.018764659890539485, 0.6818181818181818, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]'),
#  Text(0.028146989835809225, 0.7121212121212122, 'f__pymfe.landmarking.naive_bayes.histogram.3 <= 0.2\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.02501954652071931, 0.6818181818181818, 'f__pymfe.landmarking.one_nn.iq_range <= 0.037\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.0218921032056294, 0.6515151515151515, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.028146989835809225, 0.6515151515151515, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.03127443315089914, 0.6818181818181818, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.0437842064112588, 0.7424242424242424, 'f__pymfe.statistical.can_cor.histogram.9 <= 0.188\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.040656763096168884, 0.7121212121212122, 'f__pymfe.statistical.can_cor.histogram.5 <= 0.188\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.03752931978107897, 0.6818181818181818, 'f__pymfe.landmarking.worst_node.histogram.5.relative <= 2.25\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.03440187646598905, 0.6515151515151515, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.040656763096168884, 0.6515151515151515, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.0437842064112588, 0.6818181818181818, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.04691164972634871, 0.7121212121212122, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.039093041438623924, 0.7727272727272727, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.04222048475371384, 0.803030303030303, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.04534792806880375, 0.8333333333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.04847537138389367, 0.8636363636363636, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.0766223612197029, 0.8939393939393939, 'f__pymfe.landmarking.one_nn.histogram.4.relative <= 5.25\ngini = 0.077\nsamples = 200\nvalue = [192, 8]'),
#  Text(0.06098514464425332, 0.8636363636363636, 'f__pymfe.landmarking.worst_node.max <= 0.061\ngini = 0.123\nsamples = 106\nvalue = [99, 7]'),
#  Text(0.05160281469898358, 0.8333333333333334, 'f__pymfe.statistical.cor.kurtosis <= 0.33\ngini = 0.49\nsamples = 7\nvalue = [3, 4]'),
#  Text(0.04847537138389367, 0.803030303030303, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.054730258014073496, 0.803030303030303, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.07036747458952307, 0.8333333333333334, 'f__pymfe.landmarking.worst_node.histogram.7.relative <= 3.25\ngini = 0.059\nsamples = 99\nvalue = [96, 3]'),
#  Text(0.06098514464425332, 0.803030303030303, 'f__pymfe.landmarking.worst_node.quantiles.3.relative <= 1.75\ngini = 0.025\nsamples = 78\nvalue = [77, 1]'),
#  Text(0.05785770132916341, 0.7727272727272727, 'gini = 0.0\nsamples = 41\nvalue = [41, 0]'),
#  Text(0.06411258795934324, 0.7727272727272727, 'f__pymfe.statistical.kurtosis.mean <= 585.948\ngini = 0.053\nsamples = 37\nvalue = [36, 1]'),
#  Text(0.06098514464425332, 0.7424242424242424, 'gini = 0.0\nsamples = 28\nvalue = [28, 0]'),
#  Text(0.06724003127443315, 0.7424242424242424, 'f__pymfe.landmarking.linear_discr.mean.relative <= 4.5\ngini = 0.198\nsamples = 9\nvalue = [8, 1]'),
#  Text(0.06411258795934324, 0.7121212121212122, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.07036747458952307, 0.7121212121212122, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.0797498045347928, 0.803030303030303, 'f__pymfe.landmarking.linear_discr.histogram.1 <= 0.05\ngini = 0.172\nsamples = 21\nvalue = [19, 2]'),
#  Text(0.0766223612197029, 0.7727272727272727, 'f__pymfe.landmarking.best_node.skewness <= -1.394\ngini = 0.26\nsamples = 13\nvalue = [11, 2]'),
#  Text(0.07349491790461297, 0.7424242424242424, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.0797498045347928, 0.7424242424242424, 'f__pymfe.landmarking.linear_discr.histogram.0.relative <= 6.5\ngini = 0.153\nsamples = 12\nvalue = [11, 1]'),
#  Text(0.0766223612197029, 0.7121212121212122, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.08287724784988272, 0.7121212121212122, 'f__pymfe.model-based.tree_depth.histogram.3 <= 0.228\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.0797498045347928, 0.6818181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.08600469116497264, 0.6818181818181818, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.08287724784988272, 0.7727272727272727, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.09225957779515247, 0.8636363636363636, 'f__pymfe.landmarking.best_node.histogram.8 <= 0.05\ngini = 0.021\nsamples = 94\nvalue = [93, 1]'),
#  Text(0.08913213448006255, 0.8333333333333334, 'f__pymfe.model-based.leaves_branch.histogram.5 <= 0.173\ngini = 0.03\nsamples = 65\nvalue = [64, 1]'),
#  Text(0.08600469116497264, 0.803030303030303, 'gini = 0.0\nsamples = 51\nvalue = [51, 0]'),
#  Text(0.09225957779515247, 0.803030303030303, 'f__pymfe.general.freq_class.histogram.0 <= 0.091\ngini = 0.133\nsamples = 14\nvalue = [13, 1]'),
#  Text(0.08913213448006255, 0.7727272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.09538702111024237, 0.7727272727272727, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(0.09538702111024237, 0.8333333333333334, 'gini = 0.0\nsamples = 29\nvalue = [29, 0]'),
#  Text(0.18781763096168883, 0.9242424242424242, 'f__pymfe.info-theory.attr_conc.histogram.0 <= 0.123\ngini = 0.446\nsamples = 280\nvalue = [186, 94]'),
#  Text(0.18469018764659892, 0.8939393939393939, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(0.19094507427677873, 0.8939393939393939, 'f__pymfe.landmarking.one_nn.histogram.2 <= 0.05\ngini = 0.429\nsamples = 270\nvalue = [186, 84]'),
#  Text(0.14503518373729476, 0.8636363636363636, 'f__pymfe.landmarking.linear_discr.quantiles.1 <= 0.837\ngini = 0.481\nsamples = 122\nvalue = [73, 49]'),
#  Text(0.12587959343236904, 0.8333333333333334, 'f__pymfe.statistical.mean.kurtosis <= 14.133\ngini = 0.422\nsamples = 99\nvalue = [69, 30]'),
#  Text(0.11571540265832682, 0.803030303030303, 'f__pymfe.landmarking.worst_node.histogram.9.relative <= 6.25\ngini = 0.375\nsamples = 80\nvalue = [60, 20]'),
#  Text(0.10476935105551212, 0.7727272727272727, 'f__pymfe.landmarking.naive_bayes.skewness <= -0.488\ngini = 0.33\nsamples = 72\nvalue = [57, 15]'),
#  Text(0.0985144644253323, 0.7424242424242424, 'f__pymfe.landmarking.elite_nn.histogram.8.relative <= 3.25\ngini = 0.469\nsamples = 8\nvalue = [3, 5]'),
#  Text(0.09538702111024237, 0.7121212121212122, 'f__pymfe.landmarking.worst_node.iq_range <= 0.077\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.09225957779515247, 0.6818181818181818, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.0985144644253323, 0.6818181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1016419077404222, 0.7121212121212122, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.11102423768569195, 0.7424242424242424, 'f__pymfe.statistical.var.histogram.2 <= 0.202\ngini = 0.264\nsamples = 64\nvalue = [54, 10]'),
#  Text(0.10789679437060204, 0.7121212121212122, 'f__pymfe.info-theory.attr_conc.histogram.2 <= 0.034\ngini = 0.245\nsamples = 63\nvalue = [54, 9]'),
#  Text(0.10476935105551212, 0.6818181818181818, 'f__pymfe.model-based.nodes_repeated.iq_range <= 2.625\ngini = 0.286\nsamples = 52\nvalue = [43, 9]'),
#  Text(0.08835027365129007, 0.6515151515151515, 'f__pymfe.statistical.cov.max <= 383.075\ngini = 0.494\nsamples = 9\nvalue = [5, 4]'),
#  Text(0.08522283033620015, 0.6212121212121212, 'f__pymfe.model-based.tree_shape.max <= 0.438\ngini = 0.469\nsamples = 8\nvalue = [5, 3]'),
#  Text(0.08209538702111024, 0.5909090909090909, 'f__pymfe.landmarking.naive_bayes.histogram.5.relative <= 3.25\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.07896794370602032, 0.5606060606060606, 'f__pymfe.landmarking.naive_bayes.min <= 0.39\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.07584050039093042, 0.5303030303030303, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.08209538702111024, 0.5303030303030303, 'f__pymfe.landmarking.naive_bayes.histogram.8.relative <= 4.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.07896794370602032, 0.5, 'f__pymfe.landmarking.worst_node.median.relative <= 2.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.07584050039093042, 0.4696969696969697, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.08209538702111024, 0.4696969696969697, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.08522283033620015, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.08522283033620015, 0.5606060606060606, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.08835027365129007, 0.5909090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.09147771696637999, 0.6212121212121212, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.12118842845973417, 0.6515151515151515, 'f__pymfe.landmarking.elite_nn.histogram.9.relative <= 6.25\ngini = 0.206\nsamples = 43\nvalue = [38, 5]'),
#  Text(0.10711493354182955, 0.6212121212121212, 'f__pymfe.landmarking.elite_nn.histogram.4.relative <= 3.25\ngini = 0.157\nsamples = 35\nvalue = [32, 3]'),
#  Text(0.0946051602814699, 0.5909090909090909, 'f__pymfe.statistical.roy_root <= 0.151\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.09147771696637999, 0.5606060606060606, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.09773260359655982, 0.5606060606060606, 'f__pymfe.model-based.leaves_branch.histogram.7 <= 0.036\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.0946051602814699, 0.5303030303030303, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.10086004691164972, 0.5303030303030303, 'f__pymfe.statistical.mean.histogram.9 <= 0.217\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.09773260359655982, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.10398749022673964, 0.5, 'f__pymfe.statistical.kurtosis.quantiles.1 <= 5.994\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.10086004691164972, 0.4696969696969697, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.10711493354182955, 0.4696969696969697, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.11962470680218922, 0.5909090909090909, 'f__pymfe.model-based.leaves_homo.kurtosis <= 6.094\ngini = 0.069\nsamples = 28\nvalue = [27, 1]'),
#  Text(0.1164972634870993, 0.5606060606060606, 'f__pymfe.statistical.eigenvalues.histogram.2 <= 0.267\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.11336982017200939, 0.5303030303030303, 'f__pymfe.statistical.min.median <= 54.861\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.11024237685691947, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1164972634870993, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.11962470680218922, 0.5303030303030303, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.12275215011727912, 0.5606060606060606, 'gini = 0.0\nsamples = 24\nvalue = [24, 0]'),
#  Text(0.1352619233776388, 0.6212121212121212, 'f__pymfe.landmarking.best_node.histogram.6.relative <= 3.25\ngini = 0.375\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.13213448006254885, 0.5909090909090909, 'f__pymfe.statistical.range.iq_range <= 2.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.12900703674745895, 0.5606060606060606, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1352619233776388, 0.5606060606060606, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.1383893666927287, 0.5909090909090909, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.11102423768569195, 0.6818181818181818, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.11415168100078187, 0.7121212121212122, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1266614542611415, 0.7727272727272727, 'f__pymfe.landmarking.worst_node.histogram.0 <= 0.15\ngini = 0.469\nsamples = 8\nvalue = [3, 5]'),
#  Text(0.1235340109460516, 0.7424242424242424, 'f__pymfe.model-based.leaves_per_class.range <= 0.042\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.12040656763096169, 0.7121212121212122, 'f__pymfe.landmarking.one_nn.histogram.0.relative <= 4.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.11727912431587177, 0.6818181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1235340109460516, 0.6818181818181818, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1266614542611415, 0.7121212121212122, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.12978889757623144, 0.7424242424242424, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.13604378420641125, 0.803030303030303, 'f__pymfe.landmarking.elite_nn.histogram.9 <= 0.05\ngini = 0.499\nsamples = 19\nvalue = [9, 10]'),
#  Text(0.13291634089132134, 0.7727272727272727, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.13917122752150118, 0.7727272727272727, 'f__pymfe.model-based.tree_depth.histogram.7 <= 0.082\ngini = 0.375\nsamples = 12\nvalue = [9, 3]'),
#  Text(0.13604378420641125, 0.7424242424242424, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.1422986708365911, 0.7424242424242424, 'f__pymfe.model-based.tree_shape.histogram.4 <= 0.014\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.13917122752150118, 0.7121212121212122, 'f__pymfe.statistical.h_mean.iq_range <= 0.925\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.13604378420641125, 0.6818181818181818, 'f__pymfe.landmarking.best_node.histogram.6.relative <= 2.25\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.13291634089132134, 0.6515151515151515, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.13917122752150118, 0.6515151515151515, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1422986708365911, 0.6818181818181818, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.145426114151681, 0.7121212121212122, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.1641907740422205, 0.8333333333333334, 'f__pymfe.statistical.t_mean.histogram.0 <= 0.741\ngini = 0.287\nsamples = 23\nvalue = [4, 19]'),
#  Text(0.15480844409695074, 0.803030303030303, 'f__pymfe.landmarking.one_nn.histogram.3.relative <= 4.25\ngini = 0.105\nsamples = 18\nvalue = [1, 17]'),
#  Text(0.15168100078186084, 0.7727272727272727, 'f__pymfe.landmarking.worst_node.sd.relative <= 6.5\ngini = 0.165\nsamples = 11\nvalue = [1, 10]'),
#  Text(0.1485535574667709, 0.7424242424242424, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.15480844409695074, 0.7424242424242424, 'f__pymfe.statistical.cor.skewness <= -0.253\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.15168100078186084, 0.7121212121212122, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.15793588741204065, 0.7121212121212122, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.15793588741204065, 0.7727272727272727, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.17357310398749023, 0.803030303030303, 'f__pymfe.landmarking.one_nn.histogram.4.relative <= 5.75\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.1704456606724003, 0.7727272727272727, 'f__pymfe.statistical.sd.quantiles.1 <= 0.057\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.1673182173573104, 0.7424242424242424, 'f__pymfe.landmarking.naive_bayes.kurtosis.relative <= 4.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.1641907740422205, 0.7121212121212122, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1704456606724003, 0.7121212121212122, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.17357310398749023, 0.7424242424242424, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.17670054730258014, 0.7727272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2368549648162627, 0.8636363636363636, 'f__pymfe.landmarking.best_node.min <= 0.24\ngini = 0.361\nsamples = 148\nvalue = [113, 35]'),
#  Text(0.22458952306489444, 0.8333333333333334, 'f__pymfe.statistical.var.skewness <= 8.211\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.22146207974980453, 0.803030303030303, 'f__pymfe.info-theory.mut_inf.quantiles.1 <= 0.011\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.21833463643471462, 0.7727272727272727, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.22458952306489444, 0.7727272727272727, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.22771696637998437, 0.803030303030303, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.24912040656763096, 0.8333333333333334, 'f__pymfe.info-theory.ns_ratio <= 8.727\ngini = 0.335\nsamples = 141\nvalue = [111, 30]'),
#  Text(0.24599296325254105, 0.803030303030303, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.25224784988272086, 0.803030303030303, 'f__pymfe.statistical.t_mean.histogram.3 <= 0.171\ngini = 0.292\nsamples = 135\nvalue = [111, 24]'),
#  Text(0.23084440969507428, 0.7727272727272727, 'f__pymfe.statistical.kurtosis.histogram.4 <= 0.104\ngini = 0.273\nsamples = 129\nvalue = [108, 21]'),
#  Text(0.19741985926505082, 0.7424242424242424, 'f__pymfe.statistical.t_mean.median <= 4.685\ngini = 0.208\nsamples = 102\nvalue = [90, 12]'),
#  Text(0.17670054730258014, 0.7121212121212122, 'f__pymfe.model-based.tree_imbalance.histogram.2 <= 0.059\ngini = 0.057\nsamples = 34\nvalue = [33, 1]'),
#  Text(0.17357310398749023, 0.6818181818181818, 'gini = 0.0\nsamples = 20\nvalue = [20, 0]'),
#  Text(0.17982799061767005, 0.6818181818181818, 'f__pymfe.statistical.t_mean.histogram.1 <= 0.016\ngini = 0.133\nsamples = 14\nvalue = [13, 1]'),
#  Text(0.17670054730258014, 0.6515151515151515, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(0.18295543393275998, 0.6515151515151515, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2181391712275215, 0.7121212121212122, 'f__pymfe.statistical.cov.median <= 947.994\ngini = 0.271\nsamples = 68\nvalue = [57, 11]'),
#  Text(0.1970289288506646, 0.6818181818181818, 'f__pymfe.model-based.tree_depth.histogram.8 <= 0.057\ngini = 0.222\nsamples = 55\nvalue = [48, 7]'),
#  Text(0.1892103205629398, 0.6515151515151515, 'f__pymfe.statistical.skewness.histogram.4 <= 0.167\ngini = 0.074\nsamples = 26\nvalue = [25, 1]'),
#  Text(0.1860828772478499, 0.6212121212121212, 'gini = 0.0\nsamples = 23\nvalue = [23, 0]'),
#  Text(0.1923377638780297, 0.6212121212121212, 'f__pymfe.model-based.leaves_branch.histogram.4 <= 0.082\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.1892103205629398, 0.5909090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.19546520719311963, 0.5909090909090909, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.20484753713838938, 0.6515151515151515, 'f__pymfe.info-theory.mut_inf.quantiles.1 <= 0.0\ngini = 0.328\nsamples = 29\nvalue = [23, 6]'),
#  Text(0.20172009382329945, 0.6212121212121212, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.20797498045347929, 0.6212121212121212, 'f__pymfe.model-based.nodes_per_level.histogram.2 <= 0.022\ngini = 0.293\nsamples = 28\nvalue = [23, 5]'),
#  Text(0.20172009382329945, 0.5909090909090909, 'f__pymfe.landmarking.worst_node.mean.relative <= 4.25\ngini = 0.49\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.19859265050820954, 0.5606060606060606, 'f__pymfe.model-based.tree_depth.histogram.8 <= 0.075\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.19546520719311963, 0.5303030303030303, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.20172009382329945, 0.5303030303030303, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.20484753713838938, 0.5606060606060606, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2142298670836591, 0.5909090909090909, 'f__pymfe.statistical.cor.histogram.4 <= 0.029\ngini = 0.172\nsamples = 21\nvalue = [19, 2]'),
#  Text(0.2111024237685692, 0.5606060606060606, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(0.21735731039874903, 0.5606060606060606, 'f__pymfe.landmarking.one_nn.histogram.3.relative <= 4.25\ngini = 0.375\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.2142298670836591, 0.5303030303030303, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.22048475371383894, 0.5303030303030303, 'f__pymfe.landmarking.naive_bayes.histogram.8 <= 0.05\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.21735731039874903, 0.5, 'f__pymfe.statistical.h_mean.skewness <= 2.208\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.2142298670836591, 0.4696969696969697, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.22048475371383894, 0.4696969696969697, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.22361219702892884, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.23924941360437843, 0.6818181818181818, 'f__pymfe.statistical.mad.histogram.7 <= 0.003\ngini = 0.426\nsamples = 13\nvalue = [9, 4]'),
#  Text(0.2361219702892885, 0.6515151515151515, 'f__pymfe.model-based.leaves_homo.histogram.1 <= 0.037\ngini = 0.463\nsamples = 11\nvalue = [7, 4]'),
#  Text(0.2329945269741986, 0.6212121212121212, 'f__pymfe.landmarking.naive_bayes.iq_range.relative <= 4.5\ngini = 0.49\nsamples = 7\nvalue = [3, 4]'),
#  Text(0.22673964034401878, 0.5909090909090909, 'f__pymfe.landmarking.elite_nn.min.relative <= 1.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.22361219702892884, 0.5606060606060606, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.22986708365910868, 0.5606060606060606, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.23924941360437843, 0.5909090909090909, 'f__pymfe.model-based.var_importance.histogram.9 <= 0.292\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.2361219702892885, 0.5606060606060606, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.24237685691946834, 0.5606060606060606, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.23924941360437843, 0.6212121212121212, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.24237685691946834, 0.6515151515151515, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.2642689601250977, 0.7424242424242424, 'f__pymfe.statistical.h_mean.histogram.8 <= 0.056\ngini = 0.444\nsamples = 27\nvalue = [18, 9]'),
#  Text(0.2611415168100078, 0.7121212121212122, 'f__pymfe.statistical.cor.min <= 0.0\ngini = 0.453\nsamples = 26\nvalue = [17, 9]'),
#  Text(0.2580140734949179, 0.6818181818181818, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.2642689601250977, 0.6818181818181818, 'f__pymfe.statistical.min.iq_range <= 2.03\ngini = 0.483\nsamples = 22\nvalue = [13, 9]'),
#  Text(0.2580140734949179, 0.6515151515151515, 'f__pymfe.model-based.leaves_homo.min <= 436.0\ngini = 0.397\nsamples = 11\nvalue = [3, 8]'),
#  Text(0.254886630179828, 0.6212121212121212, 'f__pymfe.statistical.skewness.histogram.8 <= 0.167\ngini = 0.32\nsamples = 10\nvalue = [2, 8]'),
#  Text(0.2517591868647381, 0.5909090909090909, 'f__pymfe.model-based.leaves_branch.histogram.8 <= 0.039\ngini = 0.198\nsamples = 9\nvalue = [1, 8]'),
#  Text(0.24863174354964818, 0.5606060606060606, 'f__pymfe.statistical.sparsity.histogram.2 <= 0.014\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.24550430023455824, 0.5303030303030303, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2517591868647381, 0.5303030303030303, 'f__pymfe.model-based.tree_imbalance.quantiles.3 <= 0.107\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.24863174354964818, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.254886630179828, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.254886630179828, 0.5606060606060606, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.2580140734949179, 0.5909090909090909, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2611415168100078, 0.6212121212121212, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2705238467552776, 0.6515151515151515, 'f__pymfe.landmarking.worst_node.histogram.2.relative <= 3.25\ngini = 0.165\nsamples = 11\nvalue = [10, 1]'),
#  Text(0.26739640344018767, 0.6212121212121212, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.2736512900703675, 0.6212121212121212, 'f__pymfe.model-based.leaves_per_class.quantiles.1 <= 0.472\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.2705238467552776, 0.5909090909090909, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2767787333854574, 0.5909090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.26739640344018767, 0.7121212121212122, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2736512900703675, 0.7727272727272727, 'f__pymfe.landmarking.naive_bayes.skewness <= -0.381\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.2705238467552776, 0.7424242424242424, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2767787333854574, 0.7424242424242424, 'f__pymfe.landmarking.one_nn.histogram.8 <= 0.05\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.2736512900703675, 0.7121212121212122, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.2799061767005473, 0.7121212121212122, 'f__pymfe.model-based.leaves_corrob.mean <= 0.012\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.2767787333854574, 0.6818181818181818, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2830336200156372, 0.6818181818181818, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.7865611561767005, 0.9545454545454546, 'f__pymfe.landmarking.elite_nn.quantiles.3.relative <= 4.75\ngini = 0.499\nsamples = 1181\nvalue = [612, 569]'),
#  Text(0.608012851837373, 0.9242424242424242, 'f__pymfe.landmarking.naive_bayes.max <= 0.831\ngini = 0.5\nsamples = 1026\nvalue = [501, 525]'),
#  Text(0.5175307857701329, 0.8939393939393939, 'f__pymfe.statistical.eigenvalues.histogram.5 <= 0.0\ngini = 0.49\nsamples = 741\nvalue = [422, 319]'),
#  Text(0.4600029319781079, 0.8636363636363636, 'f__pymfe.statistical.skewness.quantiles.1 <= 0.209\ngini = 0.499\nsamples = 576\nvalue = [298, 278]'),
#  Text(0.41648749022673964, 0.8333333333333334, 'f__pymfe.statistical.eigenvalues.histogram.7 <= 0.022\ngini = 0.486\nsamples = 438\nvalue = [255, 183]'),
#  Text(0.3810594214229867, 0.803030303030303, 'f__pymfe.statistical.median.histogram.6 <= 0.022\ngini = 0.493\nsamples = 412\nvalue = [231, 181]'),
#  Text(0.3446051602814699, 0.7727272727272727, 'f__pymfe.landmarking.linear_discr.quantiles.3.relative <= 6.25\ngini = 0.5\nsamples = 326\nvalue = [167, 159]'),
#  Text(0.3232994526974199, 0.7424242424242424, 'f__pymfe.model-based.nodes_repeated.kurtosis <= -0.462\ngini = 0.5\nsamples = 291\nvalue = [142, 149]'),
#  Text(0.30414386239249414, 0.7121212121212122, 'f__pymfe.info-theory.attr_conc.max <= 0.009\ngini = 0.497\nsamples = 263\nvalue = [141, 122]'),
#  Text(0.28928850664581707, 0.6818181818181818, 'f__pymfe.info-theory.class_conc.histogram.2 <= 0.25\ngini = 0.064\nsamples = 30\nvalue = [1, 29]'),
#  Text(0.2861610633307271, 0.6515151515151515, 'gini = 0.0\nsamples = 27\nvalue = [0, 27]'),
#  Text(0.292415949960907, 0.6515151515151515, 'f__pymfe.info-theory.attr_conc.histogram.6 <= 0.067\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.28928850664581707, 0.6212121212121212, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2955433932759969, 0.6212121212121212, 'f__pymfe.info-theory.class_conc.iq_range <= 0.069\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.292415949960907, 0.5909090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2986708365910868, 0.5909090909090909, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3189992181391712, 0.6818181818181818, 'f__pymfe.model-based.leaves_branch.histogram.8 <= 0.08\ngini = 0.48\nsamples = 233\nvalue = [140, 93]'),
#  Text(0.3080531665363565, 0.6515151515151515, 'f__pymfe.landmarking.worst_node.kurtosis.relative <= 5.5\ngini = 0.484\nsamples = 224\nvalue = [132, 92]'),
#  Text(0.3049257232212666, 0.6212121212121212, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.31118060985144647, 0.6212121212121212, 'f__pymfe.info-theory.attr_ent.histogram.9 <= 0.583\ngini = 0.482\nsamples = 222\nvalue = [132, 90]'),
#  Text(0.3049257232212666, 0.5909090909090909, 'f__pymfe.landmarking.one_nn.histogram.1.relative <= 5.5\ngini = 0.499\nsamples = 184\nvalue = [95, 89]'),
#  Text(0.3017982799061767, 0.5606060606060606, 'f__pymfe.info-theory.mut_inf.quantiles.3 <= 0.009\ngini = 0.5\nsamples = 182\nvalue = [93, 89]'),
#  Text(0.2986708365910868, 0.5303030303030303, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.3049257232212666, 0.5303030303030303, 'f__pymfe.model-based.tree_imbalance.skewness <= 1.482\ngini = 0.499\nsamples = 171\nvalue = [82, 89]'),
#  Text(0.3017982799061767, 0.5, 'f__pymfe.landmarking.elite_nn.histogram.8 <= 0.05\ngini = 0.499\nsamples = 169\nvalue = [80, 89]'),
#  Text(0.2986708365910868, 0.4696969696969697, 'f__pymfe.statistical.sparsity.histogram.1 <= 0.303\ngini = 0.499\nsamples = 168\nvalue = [80, 88]'),
#  Text(0.2682759968725567, 0.4393939393939394, 'f__pymfe.info-theory.attr_conc.histogram.5 <= 0.095\ngini = 0.493\nsamples = 150\nvalue = [66, 84]'),
#  Text(0.23876075058639562, 0.4090909090909091, 'f__pymfe.general.freq_class.count <= 5.0\ngini = 0.488\nsamples = 140\nvalue = [59, 81]'),
#  Text(0.2117865519937451, 0.3787878787878788, 'f__pymfe.info-theory.attr_ent.histogram.6 <= 0.233\ngini = 0.447\nsamples = 107\nvalue = [36, 71]'),
#  Text(0.19614933541829555, 0.3484848484848485, 'f__pymfe.general.nr_attr <= 26.0\ngini = 0.418\nsamples = 94\nvalue = [28, 66]'),
#  Text(0.17425723221266615, 0.3181818181818182, 'f__pymfe.info-theory.mut_inf.histogram.9 <= 0.194\ngini = 0.316\nsamples = 66\nvalue = [13, 53]'),
#  Text(0.16331118060985145, 0.2878787878787879, 'f__pymfe.info-theory.class_conc.min <= 0.0\ngini = 0.093\nsamples = 41\nvalue = [2, 39]'),
#  Text(0.16018373729476154, 0.25757575757575757, 'f__pymfe.info-theory.joint_ent.histogram.1 <= 0.056\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.1570562939796716, 0.22727272727272727, 'f__pymfe.info-theory.attr_conc.kurtosis <= 10.1\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.1539288506645817, 0.19696969696969696, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.16018373729476154, 0.19696969696969696, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.16331118060985145, 0.22727272727272727, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.16643862392494135, 0.25757575757575757, 'gini = 0.0\nsamples = 38\nvalue = [0, 38]'),
#  Text(0.18520328381548085, 0.2878787878787879, 'f__pymfe.info-theory.class_conc.histogram.0 <= 0.611\ngini = 0.493\nsamples = 25\nvalue = [11, 14]'),
#  Text(0.18207584050039094, 0.25757575757575757, 'f__pymfe.statistical.sparsity.max <= 0.496\ngini = 0.499\nsamples = 21\nvalue = [11, 10]'),
#  Text(0.178948397185301, 0.22727272727272727, 'f__pymfe.statistical.sparsity.quantiles.3 <= 0.317\ngini = 0.499\nsamples = 19\nvalue = [9, 10]'),
#  Text(0.16643862392494135, 0.19696969696969696, 'f__pymfe.info-theory.class_ent <= 0.933\ngini = 0.486\nsamples = 12\nvalue = [7, 5]'),
#  Text(0.16331118060985145, 0.16666666666666666, 'f__pymfe.statistical.sparsity.sd <= 0.177\ngini = 0.463\nsamples = 11\nvalue = [7, 4]'),
#  Text(0.16018373729476154, 0.13636363636363635, 'f__pymfe.info-theory.ns_ratio <= 13.139\ngini = 0.48\nsamples = 10\nvalue = [6, 4]'),
#  Text(0.1508014073494918, 0.10606060606060606, 'f__pymfe.info-theory.attr_ent.max <= 4.668\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.1476739640344019, 0.07575757575757576, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1539288506645817, 0.07575757575757576, 'f__pymfe.info-theory.class_conc.iq_range <= 0.046\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.1508014073494918, 0.045454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1570562939796716, 0.045454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1695660672400313, 0.10606060606060606, 'f__pymfe.info-theory.attr_conc.max <= 0.062\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.16643862392494135, 0.07575757575757576, 'f__pymfe.general.freq_class.quantiles.1 <= 0.349\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.16331118060985145, 0.045454545454545456, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.1695660672400313, 0.045454545454545456, 'f__pymfe.info-theory.class_conc.max <= 0.087\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.16643862392494135, 0.015151515151515152, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1726935105551212, 0.015151515151515152, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1726935105551212, 0.07575757575757576, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.16643862392494135, 0.13636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1695660672400313, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.19145817044566069, 0.19696969696969696, 'f__pymfe.info-theory.attr_ent.skewness <= -0.086\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.18833072713057075, 0.16666666666666666, 'f__pymfe.info-theory.attr_conc.histogram.3 <= 0.25\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.18520328381548085, 0.13636363636363635, 'f__pymfe.info-theory.attr_conc.sd <= 0.013\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.18207584050039094, 0.10606060606060606, 'f__pymfe.info-theory.attr_ent.mean <= 2.208\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.178948397185301, 0.07575757575757576, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.18520328381548085, 0.07575757575757576, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.18833072713057075, 0.10606060606060606, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.19145817044566069, 0.13636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1945856137607506, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.18520328381548085, 0.22727272727272727, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.18833072713057075, 0.25757575757575757, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.21804143862392494, 0.3181818181818182, 'f__pymfe.info-theory.class_conc.histogram.5 <= 0.026\ngini = 0.497\nsamples = 28\nvalue = [15, 13]'),
#  Text(0.21022283033620015, 0.2878787878787879, 'f__pymfe.info-theory.class_conc.histogram.5 <= 0.009\ngini = 0.499\nsamples = 19\nvalue = [9, 10]'),
#  Text(0.20709538702111024, 0.25757575757575757, 'f__pymfe.info-theory.mut_inf.histogram.4 <= 0.014\ngini = 0.5\nsamples = 18\nvalue = [9, 9]'),
#  Text(0.2008405003909304, 0.22727272727272727, 'f__pymfe.info-theory.attr_conc.histogram.8 <= 0.008\ngini = 0.5\nsamples = 14\nvalue = [7, 7]'),
#  Text(0.1977130570758405, 0.19696969696969696, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.20396794370602034, 0.19696969696969696, 'f__pymfe.info-theory.class_conc.max <= 0.309\ngini = 0.463\nsamples = 11\nvalue = [7, 4]'),
#  Text(0.2008405003909304, 0.16666666666666666, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.20709538702111024, 0.16666666666666666, 'f__pymfe.info-theory.class_conc.kurtosis <= 9.025\ngini = 0.219\nsamples = 8\nvalue = [7, 1]'),
#  Text(0.20396794370602034, 0.13636363636363635, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.21022283033620015, 0.13636363636363635, 'f__pymfe.info-theory.attr_ent.histogram.2 <= 0.35\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.20709538702111024, 0.10606060606060606, 'f__pymfe.info-theory.joint_ent.range <= 1.25\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.20396794370602034, 0.07575757575757576, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.21022283033620015, 0.07575757575757576, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.21335027365129006, 0.10606060606060606, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.21335027365129006, 0.22727272727272727, 'f__pymfe.info-theory.attr_conc.skewness <= 3.22\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.21022283033620015, 0.19696969696969696, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.21647771696638, 0.19696969696969696, 'f__pymfe.info-theory.attr_ent.max <= 0.995\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.21335027365129006, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2196051602814699, 0.16666666666666666, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.21335027365129006, 0.25757575757575757, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.22586004691164974, 0.2878787878787879, 'f__pymfe.info-theory.attr_ent.iq_range <= 0.581\ngini = 0.444\nsamples = 9\nvalue = [6, 3]'),
#  Text(0.2227326035965598, 0.25757575757575757, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.22898749022673964, 0.25757575757575757, 'f__pymfe.info-theory.attr_ent.sd <= 0.376\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.22586004691164974, 0.22727272727272727, 'f__pymfe.info-theory.mut_inf.histogram.5 <= 0.054\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.2227326035965598, 0.19696969696969696, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.22898749022673964, 0.19696969696969696, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.23211493354182955, 0.22727272727272727, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.2274237685691947, 0.3484848484848485, 'f__pymfe.info-theory.mut_inf.kurtosis <= 25.586\ngini = 0.473\nsamples = 13\nvalue = [8, 5]'),
#  Text(0.22429632525410476, 0.3181818181818182, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.2305512118842846, 0.3181818181818182, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.2657349491790461, 0.3787878787878788, 'f__pymfe.info-theory.class_conc.histogram.1 <= 0.131\ngini = 0.422\nsamples = 33\nvalue = [23, 10]'),
#  Text(0.25557075840500393, 0.3484848484848485, 'f__pymfe.info-theory.class_conc.histogram.4 <= 0.117\ngini = 0.488\nsamples = 19\nvalue = [11, 8]'),
#  Text(0.2446247068021892, 0.3181818181818182, 'f__pymfe.statistical.sparsity.iq_range <= 0.24\ngini = 0.42\nsamples = 10\nvalue = [7, 3]'),
#  Text(0.2383698201720094, 0.2878787878787879, 'f__pymfe.info-theory.joint_ent.histogram.5 <= 0.014\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.23524237685691946, 0.25757575757575757, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.2414972634870993, 0.25757575757575757, 'f__pymfe.info-theory.class_conc.histogram.7 <= 0.3\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.2383698201720094, 0.22727272727272727, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.2446247068021892, 0.22727272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.25087959343236904, 0.2878787878787879, 'f__pymfe.info-theory.attr_conc.max <= 0.126\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.24775215011727914, 0.25757575757575757, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.25400703674745895, 0.25757575757575757, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2665168100078186, 0.3181818181818182, 'f__pymfe.info-theory.attr_ent.skewness <= 2.159\ngini = 0.494\nsamples = 9\nvalue = [4, 5]'),
#  Text(0.2633893666927287, 0.2878787878787879, 'f__pymfe.info-theory.attr_ent.median <= 0.834\ngini = 0.469\nsamples = 8\nvalue = [3, 5]'),
#  Text(0.26026192337763876, 0.25757575757575757, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.2665168100078186, 0.25757575757575757, 'f__pymfe.info-theory.joint_ent.histogram.4 <= 0.324\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.2633893666927287, 0.22727272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.26964425332290853, 0.22727272727272727, 'f__pymfe.info-theory.mut_inf.iq_range <= 0.146\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.2665168100078186, 0.19696969696969696, 'f__pymfe.info-theory.class_conc.histogram.6 <= 0.088\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.2633893666927287, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.26964425332290853, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.27277169663799844, 0.19696969696969696, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.26964425332290853, 0.2878787878787879, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.27589913995308835, 0.3484848484848485, 'f__pymfe.info-theory.joint_ent.histogram.6 <= 0.007\ngini = 0.245\nsamples = 14\nvalue = [12, 2]'),
#  Text(0.27277169663799844, 0.3181818181818182, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.27902658326817825, 0.3181818181818182, 'f__pymfe.info-theory.joint_ent.histogram.2 <= 0.007\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.27589913995308835, 0.2878787878787879, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.28215402658326816, 0.2878787878787879, 'f__pymfe.info-theory.attr_ent.histogram.8 <= 0.007\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.27902658326817825, 0.25757575757575757, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.2852814698983581, 0.25757575757575757, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.29779124315871774, 0.4090909090909091, 'f__pymfe.info-theory.mut_inf.histogram.2 <= 0.029\ngini = 0.42\nsamples = 10\nvalue = [7, 3]'),
#  Text(0.29153635652853793, 0.3787878787878788, 'f__pymfe.info-theory.joint_ent.kurtosis <= -1.53\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.288408913213448, 0.3484848484848485, 'f__pymfe.info-theory.attr_ent.median <= 2.314\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.2852814698983581, 0.3181818181818182, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.29153635652853793, 0.3181818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.29466379984362784, 0.3484848484848485, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.30404612978889756, 0.3787878787878788, 'f__pymfe.info-theory.joint_ent.histogram.2 <= 0.129\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.30091868647380765, 0.3484848484848485, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.30717357310398746, 0.3484848484848485, 'f__pymfe.info-theory.attr_conc.min <= 0.001\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.30404612978889756, 0.3181818181818182, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.3103010164190774, 0.3181818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.32906567630961686, 0.4393939393939394, 'f__pymfe.info-theory.class_conc.histogram.1 <= 0.154\ngini = 0.346\nsamples = 18\nvalue = [14, 4]'),
#  Text(0.32593823299452696, 0.4090909090909091, 'f__pymfe.info-theory.ns_ratio <= 43.549\ngini = 0.219\nsamples = 16\nvalue = [14, 2]'),
#  Text(0.32281078967943705, 0.3787878787878788, 'f__pymfe.general.freq_class.range <= 0.409\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.31968334636434714, 0.3484848484848485, 'f__pymfe.info-theory.mut_inf.kurtosis <= -1.919\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.31655590304925724, 0.3181818181818182, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.32281078967943705, 0.3181818181818182, 'f__pymfe.info-theory.joint_ent.median <= 2.092\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.31968334636434714, 0.2878787878787879, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.32593823299452696, 0.2878787878787879, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.32593823299452696, 0.3484848484848485, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.32906567630961686, 0.3787878787878788, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.3321931196247068, 0.4090909090909091, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.3049257232212666, 0.4696969696969697, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3080531665363565, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.3080531665363565, 0.5606060606060606, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.3174354964816263, 0.5909090909090909, 'f__pymfe.info-theory.class_conc.kurtosis <= -1.931\ngini = 0.051\nsamples = 38\nvalue = [37, 1]'),
#  Text(0.31430805316653637, 0.5606060606060606, 'f__pymfe.info-theory.joint_ent.sd <= 1.325\ngini = 0.219\nsamples = 8\nvalue = [7, 1]'),
#  Text(0.31118060985144647, 0.5303030303030303, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3174354964816263, 0.5303030303030303, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.3205629397967162, 0.5606060606060606, 'gini = 0.0\nsamples = 30\nvalue = [30, 0]'),
#  Text(0.3299452697419859, 0.6515151515151515, 'f__pymfe.landmarking.best_node.max.relative <= 3.25\ngini = 0.198\nsamples = 9\nvalue = [8, 1]'),
#  Text(0.326817826426896, 0.6212121212121212, 'f__pymfe.landmarking.random_node.histogram.4.relative <= 3.75\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.3236903831118061, 0.5909090909090909, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.3299452697419859, 0.5909090909090909, 'f__pymfe.landmarking.elite_nn.quantiles.3 <= 0.299\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.326817826426896, 0.5606060606060606, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.33307271305707586, 0.5606060606060606, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.33307271305707586, 0.6212121212121212, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.3424550430023456, 0.7121212121212122, 'f__pymfe.statistical.var.histogram.5 <= 0.001\ngini = 0.069\nsamples = 28\nvalue = [1, 27]'),
#  Text(0.3393275996872557, 0.6818181818181818, 'f__pymfe.model-based.tree_imbalance.histogram.2 <= 0.092\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.33620015637216577, 0.6515151515151515, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3424550430023456, 0.6515151515151515, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3455824863174355, 0.6818181818181818, 'gini = 0.0\nsamples = 26\nvalue = [0, 26]'),
#  Text(0.36591086786551996, 0.7424242424242424, 'f__pymfe.statistical.eigenvalues.min <= 0.086\ngini = 0.408\nsamples = 35\nvalue = [25, 10]'),
#  Text(0.35809225957779517, 0.7121212121212122, 'f__pymfe.statistical.sparsity.range <= 0.043\ngini = 0.476\nsamples = 23\nvalue = [14, 9]'),
#  Text(0.3518373729476153, 0.6818181818181818, 'f__pymfe.landmarking.linear_discr.kurtosis.relative <= 3.5\ngini = 0.444\nsamples = 9\nvalue = [3, 6]'),
#  Text(0.3487099296325254, 0.6515151515151515, 'f__pymfe.statistical.cor.histogram.3 <= 0.088\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.3455824863174355, 0.6212121212121212, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
# ...
#  Text(0.7763878029710711, 0.5909090909090909, 'f__pymfe.landmarking.one_nn.histogram.9.relative <= 6.75\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.7732603596559813, 0.5606060606060606, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.7795152462861611, 0.5606060606060606, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7826426896012509, 0.5909090909090909, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.7857701329163409, 0.6212121212121212, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.7888975762314308, 0.6515151515151515, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.7888975762314308, 0.7121212121212122, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.7951524628616107, 0.7727272727272727, 'f__pymfe.model-based.var_importance.kurtosis <= 21.297\ngini = 0.346\nsamples = 9\nvalue = [7, 2]'),
#  Text(0.7920250195465207, 0.7424242424242424, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.7982799061767005, 0.7424242424242424, 'f__pymfe.statistical.min.quantiles.1 <= 0.002\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.7951524628616107, 0.7121212121212122, 'f__pymfe.model-based.tree_shape.kurtosis <= -1.51\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.7920250195465207, 0.6818181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7982799061767005, 0.6818181818181818, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.8014073494917905, 0.7121212121212122, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8209538702111024, 0.803030303030303, 'f__pymfe.landmarking.elite_nn.kurtosis.relative <= 1.5\ngini = 0.426\nsamples = 39\nvalue = [27, 12]'),
#  Text(0.8076622361219703, 0.7727272727272727, 'f__pymfe.statistical.skewness.min <= -1.166\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.8045347928068803, 0.7424242424242424, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.8107896794370602, 0.7424242424242424, 'f__pymfe.landmarking.best_node.histogram.7 <= 0.1\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.8076622361219703, 0.7121212121212122, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.8139171227521501, 0.7121212121212122, 'f__pymfe.landmarking.random_node.histogram.1 <= 0.05\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.8107896794370602, 0.6818181818181818, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.8170445660672401, 0.6818181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8342455043002346, 0.7727272727272727, 'f__pymfe.general.freq_class.histogram.5 <= 0.5\ngini = 0.342\nsamples = 32\nvalue = [25, 7]'),
#  Text(0.8264268960125097, 0.7424242424242424, 'f__pymfe.landmarking.elite_nn.iq_range <= 0.118\ngini = 0.293\nsamples = 28\nvalue = [23, 5]'),
#  Text(0.8232994526974199, 0.7121212121212122, 'gini = 0.0\nsamples = 17\nvalue = [17, 0]'),
#  Text(0.8295543393275997, 0.7121212121212122, 'f__pymfe.landmarking.naive_bayes.histogram.1.relative <= 4.5\ngini = 0.496\nsamples = 11\nvalue = [6, 5]'),
#  Text(0.8232994526974199, 0.6818181818181818, 'f__pymfe.landmarking.linear_discr.iq_range <= 0.081\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.8201720093823299, 0.6515151515151515, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8264268960125097, 0.6515151515151515, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.8358092259577795, 0.6818181818181818, 'f__pymfe.landmarking.random_node.median.relative <= 5.75\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.8326817826426895, 0.6515151515151515, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.8389366692728695, 0.6515151515151515, 'f__pymfe.statistical.eigenvalues.histogram.1 <= 0.25\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.8358092259577795, 0.6212121212121212, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8420641125879593, 0.6212121212121212, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8420641125879593, 0.7424242424242424, 'f__pymfe.model-based.tree_imbalance.kurtosis <= -0.736\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.8389366692728695, 0.7121212121212122, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8451915559030493, 0.7121212121212122, 'f__pymfe.statistical.eigenvalues.quantiles.1 <= 603.72\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.8420641125879593, 0.6818181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8483189992181391, 0.6818181818181818, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.9651094605160282, 0.9242424242424242, 'f__pymfe.statistical.mean.histogram.1 <= 0.029\ngini = 0.407\nsamples = 155\nvalue = [111, 44]'),
#  Text(0.9427286942924159, 0.8939393939393939, 'f__pymfe.statistical.iq_range.kurtosis <= 0.499\ngini = 0.463\nsamples = 110\nvalue = [70, 40]'),
#  Text(0.9167318217357311, 0.8636363636363636, 'f__pymfe.landmarking.naive_bayes.quantiles.1.relative <= 5.25\ngini = 0.486\nsamples = 84\nvalue = [49, 35]'),
#  Text(0.8897576231430805, 0.8333333333333334, 'f__pymfe.info-theory.attr_conc.median <= 0.064\ngini = 0.422\nsamples = 53\nvalue = [37, 16]'),
#  Text(0.8866301798279906, 0.803030303030303, 'f__pymfe.landmarking.one_nn.max <= 0.883\ngini = 0.385\nsamples = 50\nvalue = [37, 13]'),
#  Text(0.8717748240813136, 0.7727272727272727, 'f__pymfe.landmarking.worst_node.median <= 0.513\ngini = 0.245\nsamples = 35\nvalue = [30, 5]'),
#  Text(0.8639562157935887, 0.7424242424242424, 'f__pymfe.statistical.cor.histogram.4 <= 0.114\ngini = 0.175\nsamples = 31\nvalue = [28, 3]'),
#  Text(0.8577013291634089, 0.7121212121212122, 'f__pymfe.info-theory.mut_inf.max <= 0.059\ngini = 0.142\nsamples = 26\nvalue = [24, 2]'),
#  Text(0.854573885848319, 0.6818181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8608287724784989, 0.6818181818181818, 'f__pymfe.landmarking.one_nn.sd <= 0.024\ngini = 0.077\nsamples = 25\nvalue = [24, 1]'),
#  Text(0.8577013291634089, 0.6515151515151515, 'f__pymfe.statistical.cov.median <= 6.949\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.854573885848319, 0.6212121212121212, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.8608287724784989, 0.6212121212121212, 'f__pymfe.landmarking.naive_bayes.histogram.6.relative <= 3.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.8577013291634089, 0.5909090909090909, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8639562157935887, 0.5909090909090909, 'f__pymfe.statistical.kurtosis.quantiles.3 <= -0.089\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.8608287724784989, 0.5606060606060606, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8670836591086787, 0.5606060606060606, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8639562157935887, 0.6515151515151515, 'gini = 0.0\nsamples = 20\nvalue = [20, 0]'),
#  Text(0.8702111024237685, 0.7121212121212122, 'f__pymfe.landmarking.elite_nn.histogram.9.relative <= 6.25\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.8670836591086787, 0.6818181818181818, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.8733385457388585, 0.6818181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8795934323690383, 0.7424242424242424, 'f__pymfe.statistical.median.histogram.0 <= 0.182\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.8764659890539483, 0.7121212121212122, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.8827208756841283, 0.7121212121212122, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.9014855355746677, 0.7727272727272727, 'f__pymfe.landmarking.naive_bayes.histogram.0.relative <= 3.75\ngini = 0.498\nsamples = 15\nvalue = [7, 8]'),
#  Text(0.8921032056293979, 0.7424242424242424, 'f__pymfe.statistical.var.min <= 0.88\ngini = 0.42\nsamples = 10\nvalue = [3, 7]'),
#  Text(0.8889757623143081, 0.7121212121212122, 'f__pymfe.statistical.can_cor.min <= 0.192\ngini = 0.346\nsamples = 9\nvalue = [2, 7]'),
#  Text(0.8858483189992181, 0.6818181818181818, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8921032056293979, 0.6818181818181818, 'f__pymfe.model-based.nodes_per_level.skewness <= 0.677\ngini = 0.219\nsamples = 8\nvalue = [1, 7]'),
#  Text(0.8889757623143081, 0.6515151515151515, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.8952306489444879, 0.6515151515151515, 'f__pymfe.landmarking.elite_nn.quantiles.3 <= 0.947\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.8921032056293979, 0.6212121212121212, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.8983580922595777, 0.6212121212121212, 'f__pymfe.statistical.can_cor.iq_range <= 0.241\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.8952306489444879, 0.5909090909090909, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9014855355746677, 0.5909090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8952306489444879, 0.7121212121212122, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9108678655199375, 0.7424242424242424, 'f__pymfe.model-based.tree_imbalance.max <= 0.379\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.9077404222048475, 0.7121212121212122, 'f__pymfe.model-based.leaves_per_class.histogram.5 <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.9046129788897577, 0.6818181818181818, 'f__pymfe.landmarking.best_node.histogram.9.relative <= 6.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.9014855355746677, 0.6515151515151515, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.9077404222048475, 0.6515151515151515, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9108678655199375, 0.6818181818181818, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9139953088350273, 0.7121212121212122, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8928850664581705, 0.803030303030303, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.9437060203283816, 0.8333333333333334, 'f__pymfe.info-theory.attr_conc.histogram.7 <= 0.004\ngini = 0.475\nsamples = 31\nvalue = [12, 19]'),
#  Text(0.9374511336982018, 0.803030303030303, 'f__pymfe.landmarking.naive_bayes.histogram.8 <= 0.05\ngini = 0.444\nsamples = 27\nvalue = [9, 18]'),
#  Text(0.9343236903831118, 0.7727272727272727, 'f__pymfe.statistical.range.histogram.5 <= 0.028\ngini = 0.49\nsamples = 21\nvalue = [9, 12]'),
#  Text(0.928068803752932, 0.7424242424242424, 'f__pymfe.landmarking.linear_discr.iq_range <= 0.186\ngini = 0.43\nsamples = 16\nvalue = [5, 11]'),
#  Text(0.924941360437842, 0.7121212121212122, 'f__pymfe.statistical.skewness.skewness <= -0.058\ngini = 0.391\nsamples = 15\nvalue = [4, 11]'),
#  Text(0.9218139171227522, 0.6818181818181818, 'f__pymfe.statistical.median.min <= 36.5\ngini = 0.463\nsamples = 11\nvalue = [4, 7]'),
#  Text(0.9139953088350273, 0.6515151515151515, 'f__pymfe.statistical.skewness.skewness <= -0.067\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.9108678655199375, 0.6212121212121212, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.9171227521501173, 0.6212121212121212, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9296325254104769, 0.6515151515151515, 'f__pymfe.landmarking.best_node.range.relative <= 6.75\ngini = 0.49\nsamples = 7\nvalue = [3, 4]'),
#  Text(0.9233776387802971, 0.6212121212121212, 'f__pymfe.landmarking.random_node.histogram.3 <= 0.25\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.9202501954652071, 0.5909090909090909, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.9265050820953871, 0.5909090909090909, 'f__pymfe.statistical.cov.histogram.9 <= 0.044\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.9233776387802971, 0.5606060606060606, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9296325254104769, 0.5606060606060606, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9358874120406567, 0.6212121212121212, 'f__pymfe.landmarking.linear_discr.sd.relative <= 3.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.9327599687255669, 0.5909090909090909, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9390148553557467, 0.5909090909090909, 'f__pymfe.landmarking.elite_nn.skewness.relative <= 4.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.9358874120406567, 0.5606060606060606, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9421422986708365, 0.5606060606060606, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.928068803752932, 0.6818181818181818, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.9311962470680218, 0.7121212121212122, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9405785770132916, 0.7424242424242424, 'f__pymfe.statistical.var.skewness <= 0.512\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.9374511336982018, 0.7121212121212122, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.9437060203283816, 0.7121212121212122, 'f__pymfe.info-theory.attr_ent.histogram.0 <= 0.141\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.9405785770132916, 0.6818181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9468334636434714, 0.6818181818181818, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.9405785770132916, 0.7727272727272727, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.9499609069585614, 0.803030303030303, 'f__pymfe.landmarking.best_node.quantiles.1.relative <= 2.75\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.9468334636434714, 0.7727272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9530883502736512, 0.7727272727272727, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.9687255668491008, 0.8636363636363636, 'f__pymfe.landmarking.naive_bayes.min.relative <= 6.5\ngini = 0.311\nsamples = 26\nvalue = [21, 5]'),
#  Text(0.965598123534011, 0.8333333333333334, 'f__pymfe.statistical.cor.histogram.8 <= 0.242\ngini = 0.159\nsamples = 23\nvalue = [21, 2]'),
#  Text(0.962470680218921, 0.803030303030303, 'f__pymfe.model-based.leaves_per_class.mean <= 0.225\ngini = 0.087\nsamples = 22\nvalue = [21, 1]'),
#  Text(0.9593432369038312, 0.7727272727272727, 'f__pymfe.landmarking.one_nn.histogram.0 <= 0.25\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.9562157935887412, 0.7424242424242424, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.962470680218921, 0.7424242424242424, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.965598123534011, 0.7727272727272727, 'gini = 0.0\nsamples = 17\nvalue = [17, 0]'),
#  Text(0.9687255668491008, 0.803030303030303, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9718530101641908, 0.8333333333333334, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.9874902267396404, 0.8939393939393939, 'f__pymfe.statistical.median.histogram.8 <= 0.026\ngini = 0.162\nsamples = 45\nvalue = [41, 4]'),
#  Text(0.9812353401094606, 0.8636363636363636, 'f__pymfe.info-theory.class_conc.histogram.3 <= 0.05\ngini = 0.108\nsamples = 35\nvalue = [33, 2]'),
#  Text(0.9781078967943706, 0.8333333333333334, 'f__pymfe.landmarking.naive_bayes.quantiles.3.relative <= 6.5\ngini = 0.137\nsamples = 27\nvalue = [25, 2]'),
#  Text(0.9749804534792806, 0.803030303030303, 'f__pymfe.info-theory.joint_ent.quantiles.1 <= 2.434\ngini = 0.074\nsamples = 26\nvalue = [25, 1]'),
#  Text(0.9718530101641908, 0.7727272727272727, 'gini = 0.0\nsamples = 22\nvalue = [22, 0]'),
#  Text(0.9781078967943706, 0.7727272727272727, 'f__pymfe.landmarking.naive_bayes.mean.relative <= 5.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.9749804534792806, 0.7424242424242424, 'f__pymfe.model-based.leaves_branch.skewness <= 0.496\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.9718530101641908, 0.7121212121212122, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.9781078967943706, 0.7121212121212122, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9812353401094606, 0.7424242424242424, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9812353401094606, 0.803030303030303, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9843627834245504, 0.8333333333333334, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.9937451133698202, 0.8636363636363636, 'f__pymfe.model-based.nodes_repeated.sd <= 24.723\ngini = 0.32\nsamples = 10\nvalue = [8, 2]'),
#  Text(0.9906176700547302, 0.8333333333333334, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.99687255668491, 0.8333333333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]')]

# %%
r = tree.export_text(clf, feature_names=feature_cols)
print(r)
# Out:
# |--- f__pymfe.landmarking.one_nn.max <= 0.97
# |   |--- f__pymfe.model-based.nodes_repeated.range <= 13.50
# |   |   |--- f__pymfe.general.nr_inst <= 11516.50
# |   |   |   |--- f__pymfe.landmarking.elite_nn.range <= 0.14
# |   |   |   |   |--- f__pymfe.statistical.cor.histogram.1 <= 0.20
# |   |   |   |   |   |--- f__pymfe.general.inst_to_attr <= 61.48
# |   |   |   |   |   |   |--- f__pymfe.statistical.g_mean.histogram.1 <= 0.03
# |   |   |   |   |   |   |   |--- f__pymfe.general.nr_inst <= 88.00
# |   |   |   |   |   |   |   |   |--- f__pymfe.statistical.sparsity.quantiles.3 <= 0.48
# |   |   |   |   |   |   |   |   |   |--- f__pymfe.info-theory.attr_conc.quantiles.1 <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- f__pymfe.info-theory.attr_conc.max <= 0.03
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- f__pymfe.info-theory.attr_conc.max >  0.03
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- f__pymfe.info-theory.attr_conc.quantiles.1 >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- f__pymfe.statistical.sparsity.quantiles.3 >  0.48
# |   |   |   |   |   |   |   |   |   |--- f__pymfe.info-theory.mut_inf.histogram.4 <= 0.17
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- f__pymfe.info-theory.mut_inf.histogram.4 >  0.17
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- f__pymfe.general.nr_inst >  88.00
# |   |   |   |   |   |   |   |   |--- f__pymfe.model-based.nodes_per_level.histogram.3 <= 0.20
# |   |   |   |   |   |   |   |   |   |--- f__pymfe.model-based.tree_depth.histogram.9 <= 0.03
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- f__pymfe.model-based.tree_depth.histogram.9 >  0.03
# |   |   |   |   |   |   |   |   |   |   |--- f__pymfe.landmarking.naive_bayes.iq_range <= 0.09
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- f__pymfe.landmarking.naive_bayes.iq_range >  0.09
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- f__pymfe.model-based.nodes_per_level.histogram.3 >  0.20
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- f__pymfe.statistical.g_mean.histogram.1 >  0.03
# |   |   |   |   |   |   |   |--- f__pymfe.model-based.tree_shape.histogram.3 <= 0.08
# |   |   |   |   |   |   |   |   |--- f__pymfe.landmarking.one_nn.histogram.2 <= 0.15
# |   |   |   |   |   |   |   |   |   |--- f__pymfe.statistical.range.histogram.3 <= 0.14
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- f__pymfe.statistical.range.histogram.3 >  0.14
# |   |   |   |   |   |   |   |   |   |   |--- f__pymfe.statistical.sparsity.histogram.2 <= 0.23
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- f__pymfe.statistical.sparsity.histogram.2 >  0.23
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- f__pymfe.landmarking.one_nn.histogram.2 >  0.15
# |   |   |   |   |   |   |   |   |   |--- f__pymfe.general.freq_class.range <= 0.01
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- f__pymfe.general.freq_class.range >  0.01
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- f__pymfe.model-based.tree_shape.histogram.3 >  0.08
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- f__pymfe.general.inst_to_attr >  61.48
# |   |   |   |   |   |   |--- f__pymfe.info-theory.attr_ent.histogram.2 <= 0.17
# |   |   |   |   |   |   |   |--- f__pymfe.landmarking.naive_bayes.iq_range <= 0.03
# |   |   |   |   |   |   |   |   |--- f__pymfe.info-theory.attr_ent.quantiles.3 <= 0.90
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- f__pymfe.info-theory.attr_ent.quantiles.3 >  0.90
# |   |   |   |   |   |   |   |   |   |--- f__pymfe.info-theory.class_conc.min <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- f__pymfe.info-theory.class_conc.min >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- f__pymfe.info-theory.attr_conc.skewness <= 0.24
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- f__pymfe.info-theory.attr_conc.skewness >  0.24
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- f__pymfe.landmarking.naive_bayes.iq_range >  0.03
# |   |   |   |   |   |   |   |   |--- f__pymfe.info-theory.class_conc.range <= 0.21
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- f__pymfe.info-theory.class_conc.range >  0.21
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- f__pymfe.info-theory.attr_ent.histogram.2 >  0.17
# |   |   |   |   |   |   |   |--- f__pymfe.info-theory.joint_ent.sd <= 0.30
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- f__pymfe.info-theory.joint_ent.sd >  0.30
# |   |   |   |   |   |   |   |   |--- f__pymfe.info-theory.attr_ent.quantiles.3 <= 2.69
# |   |   |   |   |   |   |   |   |   |--- f__pymfe.general.freq_class.median <= 0.16
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- f__pymfe.general.freq_class.median >  0.16
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- f__pymfe.info-theory.attr_ent.quantiles.3 >  2.69
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- f__pymfe.statistical.cor.histogram.1 >  0.20
# |   |   |   |   |   |--- f__pymfe.model-based.tree_imbalance.iq_range <= 0.00
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- f__pymfe.model-based.tree_imbalance.iq_range >  0.00
# |   |   |   |   |   |   |--- f__pymfe.model-based.nodes_repeated.quantiles.1 <= 9.75
# |   |   |   |   |   |   |   |--- f__pymfe.statistical.kurtosis.histogram.3 <= 0.33
# |   |   |   |   |   |   |   |   |--- f__pymfe.model-based.tree_depth.histogram.3 <= 0.29
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- f__pymfe.model-based.tree_depth.histogram.3 >  0.29
# |   |   |   |   |   |   |   |   |   |--- f__pymfe.statistical.skewness.histogram.3 <= 0.10
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- f__pymfe.statistical.skewness.histogram.3 >  0.10
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- f__pymfe.statistical.kurtosis.histogram.3 >  0.33
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- f__pymfe.model-based.nodes_repeated.quantiles.1 >  9.75
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- f__pymfe.landmarking.elite_nn.range >  0.14
# |   |   |   |   |--- f__pymfe.info-theory.eq_num_attr <= 5.33
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- f__pymfe.info-theory.eq_num_attr >  5.33
# |   |   |   |   |   |--- f__pymfe.statistical.h_mean.histogram.2 <= 0.10
# |   |   |   |   |   |   |--- f__pymfe.model-based.leaves_homo.min <= 132.00
# |   |   |   |   |   |   |   |--- f__pymfe.model-based.leaves_branch.histogram.7 <= 0.04
# |   |   |   |   |   |   |   |   |--- f__pymfe.statistical.cov.skewness <= 0.37
# |   |   |   |   |   |   |   |   |   |--- f__pymfe.statistical.min.histogram.9 <= 0.27
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- f__pymfe.statistical.min.histogram.9 >  0.27
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- f__pymfe.statistical.cov.skewness >  0.37
# |   |   |   |   |   |   |   |   |   |--- f__pymfe.landmarking.one_nn.iq_range <= 0.04
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- f__pymfe.landmarking.one_nn.iq_range >  0.04
# |   |   |   |   |   |   |   |   |   |   |--- f__pymfe.info-theory.class_conc.histogram.8 <= 0.08
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- f__pymfe.info-theory.class_conc.histogram.8 >  0.08
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- f__pymfe.model-based.leaves_branch.histogram.7 >  0.04
# |   |   |   |   |   |   |   |   |--- f__pymfe.model-based.tree_imbalance.histogram.8 <= 0.12
# |   |   |   |   |   |   |   |   |   |--- f__pymfe.model-based.nodes_per_level.histogram.1 <= 0.18
# |   |   |   |   |   |   |   |   |   |   |--- f__pymfe.landmarking.linear_discr.kurtosis <= -1.68
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- f__pymfe.landmarking.linear_discr.kurtosis >  -1.68
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- f__pymfe.model-based.nodes_per_level.histogram.1 >  0.18
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- f__pymfe.model-based.tree_imbalance.histogram.8 >  0.12
# |   |   |   |   |   |   |   |   |   |--- f__pymfe.landmarking.random_node.quantiles.3 <= 0.84
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- f__pymfe.landmarking.random_node.quantiles.3 >  0.84
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- f__pymfe.model-based.leaves_homo.min >  132.00
# |   |   |   |   |   |   |   |--- f__pymfe.statistical.sparsity.skewness <= 6.97
# |   |   |   |   |   |   |   |   |--- f__pymfe.statistical.kurtosis.histogram.4 <= 0.12
# |   |   |   |   |   |   |   |   |   |--- f__pymfe.landmarking.best_node.histogram.9.relative <= 1.75
# |   |   |   |   |   |   |   |   |   |   |--- f__pymfe.landmarking.worst_node.histogram.5.relative <= 2.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- f__pymfe.landmarking.worst_node.histogram.5.relative >  2.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- f__pymfe.landmarking.best_node.histogram.9.relative >  1.75
# |   |   |   |   |   |   |   |   |   |   |--- f__pymfe.landmarking.elite_nn.min.relative <= 6.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- f__pymfe.landmarking.elite_nn.min.relative >  6.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- f__pymfe.statistical.kurtosis.histogram.4 >  0.12
# |   |   |   |   |   |   |   |   |   |--- f__pymfe.statistical.skewness.histogram.8 <= 0.04
# |   |   |   |   |   |   |   |   |   |   |--- f__pymfe.landmarking.elite_nn.sd <= 0.05
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- f__pymfe.landmarking.elite_nn.sd >  0.05
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- f__pymfe.statistical.skewness.histogram.8 >  0.04
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- f__pymfe.statistical.sparsity.skewness >  6.97
# |   |   |   |   |   |   |   |   |--- f__pymfe.model-based.nodes_repeated.histogram.2 <= 0.20
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- f__pymfe.model-based.nodes_repeated.histogram.2 >  0.20
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- f__pymfe.statistical.h_mean.histogram.2 >  0.10
# |   |   |   |   |   |   |--- f__pymfe.landmarking.random_node.skewness <= 0.11
# |   |   |   |   |   |   |   |--- f__pymfe.landmarking.worst_node.mean.relative <= 2.25
# |   |   |   |   |   |   |   |   |--- f__pymfe.landmarking.linear_discr.quantiles.1 <= 0.58
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- f__pymfe.landmarking.linear_discr.quantiles.1 >  0.58
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- f__pymfe.landmarking.worst_node.mean.relative >  2.25
# |   |   |   |   |   |   |   |   |--- f__pymfe.statistical.cov.skewness <= 4.86
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- f__pymfe.statistical.cov.skewness >  4.86
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- f__pymfe.landmarking.random_node.skewness >  0.11
# |   |   |   |   |   |   |   |--- f__pymfe.model-based.leaves_branch.skewness <= 0.87
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- f__pymfe.model-based.leaves_branch.skewness >  0.87
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |--- f__pymfe.general.nr_inst >  11516.50
# |   |   |   |--- f__pymfe.model-based.nodes_per_level.histogram.2 <= 0.01
# |   |   |   |   |--- class: 1
# |   |   |   |--- f__pymfe.model-based.nodes_per_level.histogram.2 >  0.01
# |   |   |   |   |--- class: 0
# |   |--- f__pymfe.model-based.nodes_repeated.range >  13.50
# |   |   |--- f__pymfe.statistical.can_cor.range <= 0.76
# |   |   |   |--- f__pymfe.statistical.min.quantiles.3 <= 12.89
# |   |   |   |   |--- f__pymfe.info-theory.ns_ratio <= 5.93
# |   |   |   |   |   |--- f__pymfe.model-based.nodes_per_level.histogram.2 <= 0.06
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- f__pymfe.model-based.nodes_per_level.histogram.2 >  0.06
# |   |   |   |   |   |   |--- f__pymfe.landmarking.one_nn.mean <= 0.30
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- f__pymfe.landmarking.one_nn.mean >  0.30
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- f__pymfe.info-theory.ns_ratio >  5.93
# |   |   |   |   |   |--- f__pymfe.model-based.tree_imbalance.mean <= 0.07
# |   |   |   |   |   |   |--- f__pymfe.model-based.nodes_per_level.histogram.9 <= 0.03
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- f__pymfe.model-based.nodes_per_level.histogram.9 >  0.03
# |   |   |   |   |   |   |   |--- f__pymfe.model-based.leaves_branch.histogram.7 <= 0.25
# |   |   |   |   |   |   |   |   |--- f__pymfe.statistical.var.histogram.4 <= 0.31
# |   |   |   |   |   |   |   |   |   |--- f__pymfe.landmarking.worst_node.histogram.7 <= 0.45
# |   |   |   |   |   |   |   |   |   |   |--- f__pymfe.info-theory.attr_conc.sd <= 0.42
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- f__pymfe.info-theory.attr_conc.sd >  0.42
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- f__pymfe.landmarking.worst_node.histogram.7 >  0.45
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- f__pymfe.statistical.var.histogram.4 >  0.31
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- f__pymfe.model-based.leaves_branch.histogram.7 >  0.25
# |   |   |   |   |   |   |   |   |--- f__pymfe.model-based.leaves_per_class.quantiles.3 <= 0.45
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- f__pymfe.model-based.leaves_per_class.quantiles.3 >  0.45
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- f__pymfe.model-based.tree_imbalance.mean >  0.07
# |   |   |   |   |   |   |--- f__pymfe.model-based.leaves_homo.histogram.5 <= 0.09
# |   |   |   |   |   |   |   |--- f__pymfe.landmarking.random_node.sd <= 0.02
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- f__pymfe.landmarking.random_node.sd >  0.02
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- f__pymfe.model-based.leaves_homo.histogram.5 >  0.09
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- f__pymfe.statistical.min.quantiles.3 >  12.89
# |   |   |   |   |--- f__pymfe.model-based.nodes_per_attr <= 41.38
# |   |   |   |   |   |--- f__pymfe.model-based.leaves_branch.histogram.5 <= 0.29
# |   |   |   |   |   |   |--- f__pymfe.model-based.leaves_branch.histogram.8 <= 0.12
# |   |   |   |   |   |   |   |--- f__pymfe.landmarking.linear_discr.histogram.9.relative <= 2.25
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- f__pymfe.landmarking.linear_discr.histogram.9.relative >  2.25
# |   |   |   |   |   |   |   |   |--- f__pymfe.statistical.cov.skewness <= 0.95
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- f__pymfe.statistical.cov.skewness >  0.95
# |   |   |   |   |   |   |   |   |   |--- f__pymfe.model-based.leaves_branch.histogram.0 <= 0.01
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- f__pymfe.model-based.leaves_branch.histogram.0 >  0.01
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- f__pymfe.model-based.leaves_branch.histogram.8 >  0.12
# |   |   |   |   |   |   |   |--- f__pymfe.landmarking.elite_nn.quantiles.1 <= 0.45
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- f__pymfe.landmarking.elite_nn.quantiles.1 >  0.45
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- f__pymfe.model-based.leaves_branch.histogram.5 >  0.29
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- f__pymfe.model-based.nodes_per_attr >  41.38
# |   |   |   |   |   |--- class: 1
# |   |   |--- f__pymfe.statistical.can_cor.range >  0.76
# |   |   |   |--- f__pymfe.landmarking.random_node.mean <= 0.20
# |   |   |   |   |--- f__pymfe.model-based.tree_shape.histogram.7 <= 0.00
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- f__pymfe.model-based.tree_shape.histogram.7 >  0.00
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- f__pymfe.landmarking.random_node.mean >  0.20
# |   |   |   |   |--- f__pymfe.landmarking.worst_node.range <= 0.05
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- f__pymfe.landmarking.worst_node.range >  0.05
# |   |   |   |   |   |--- class: 1
# |--- f__pymfe.landmarking.one_nn.max >  0.97
# |   |--- f__pymfe.statistical.cov.skewness <= -0.35
# |   |   |--- f__pymfe.model-based.leaves_corrob.sd <= 0.09
# |   |   |   |--- class: 1
# |   |   |--- f__pymfe.model-based.leaves_corrob.sd >  0.09
# |   |   |   |--- class: 0
# |   |--- f__pymfe.statistical.cov.skewness >  -0.35
# |   |   |--- f__pymfe.statistical.cov.iq_range <= 2.68
# |   |   |   |--- f__pymfe.model-based.nodes_per_level.histogram.7 <= 0.17
# |   |   |   |   |--- f__pymfe.model-based.nodes_repeated.sd <= 3.91
# |   |   |   |   |   |--- f__pymfe.statistical.h_mean.quantiles.3 <= 8.97
# |   |   |   |   |   |   |--- f__pymfe.model-based.tree_depth.kurtosis <= -1.01
# |   |   |   |   |   |   |   |--- f__pymfe.landmarking.elite_nn.histogram.6.relative <= 5.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- f__pymfe.landmarking.elite_nn.histogram.6.relative >  5.50
# |   |   |   |   |   |   |   |   |--- f__pymfe.landmarking.worst_node.iq_range.relative <= 5.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- f__pymfe.landmarking.worst_node.iq_range.relative >  5.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- f__pymfe.model-based.tree_depth.kurtosis >  -1.01
# |   |   |   |   |   |   |   |--- f__pymfe.landmarking.naive_bayes.histogram.5.relative <= 6.75
# |   |   |   |   |   |   |   |   |--- f__pymfe.statistical.kurtosis.kurtosis <= 47.18
# |   |   |   |   |   |   |   |   |   |--- f__pymfe.statistical.cor.histogram.1 <= 0.32
# |   |   |   |   |   |   |   |   |   |   |--- f__pymfe.model-based.tree_depth.skewness <= -0.68
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- f__pymfe.model-based.tree_depth.skewness >  -0.68
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- f__pymfe.statistical.cor.histogram.1 >  0.32
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- f__pymfe.statistical.kurtosis.kurtosis >  47.18
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- f__pymfe.landmarking.naive_bayes.histogram.5.relative >  6.75
# |   |   |   |   |   |   |   |   |--- f__pymfe.landmarking.linear_discr.histogram.1 <= 0.40
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- f__pymfe.landmarking.linear_discr.histogram.1 >  0.40
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- f__pymfe.statistical.h_mean.quantiles.3 >  8.97
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- f__pymfe.model-based.nodes_repeated.sd >  3.91
# |   |   |   |   |   |--- f__pymfe.landmarking.linear_discr.min <= 0.78
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- f__pymfe.landmarking.linear_discr.min >  0.78
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- f__pymfe.model-based.nodes_per_level.histogram.7 >  0.17
# |   |   |   |   |--- class: 0
# |   |   |--- f__pymfe.statistical.cov.iq_range >  2.68
# |   |   |   |--- f__pymfe.statistical.mad.histogram.8 <= 0.31
# |   |   |   |   |--- f__pymfe.statistical.can_cor.mean <= 0.94
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- f__pymfe.statistical.can_cor.mean >  0.94
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- f__pymfe.statistical.mad.histogram.8 >  0.31
# |   |   |   |   |--- class: 0

# %% [markdown]
# ### find the importance of each pair of features using logistic regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import log_loss
from sklearn.preprocessing import RobustScaler

import itertools

f1 = feature_cols[0]
f2 = feature_cols[100]

target_col = "baseline_win"

y = best_alg_df_dict[metric].loc[:, target_col].values
x =  best_alg_df_dict[metric].loc[:, feature_cols].values
x_scaled = RobustScaler().fit_transform(x)
cls_func = LogisticRegression

feature_losses = []

for i in range(len(feature_cols)):
    x_feature = x_scaled[:, i].reshape(-1, 1)
    clf = cls_func(max_iter=1000).fit(x_feature, y)
    feature_losses.append(log_loss(y, clf.predict_proba(x_feature)))

# for f1, f2 in itertools.combinations(feature_cols, 2):
# Out:
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
sorted_inds = np.array(feature_losses).argsort()

for i in range(20):
    print(f"{i} | {feature_cols[sorted_inds[i]]} : {feature_losses[sorted_inds[i]]:.3f}")
# Out:
# 0 | f__pymfe.landmarking.one_nn.max : 0.608
# 1 | f__pymfe.landmarking.linear_discr.quantiles.3 : 0.612
# 2 | f__pymfe.landmarking.linear_discr.max : 0.615
# 3 | f__pymfe.landmarking.one_nn.quantiles.3 : 0.615
# 4 | f__pymfe.landmarking.linear_discr.mean : 0.616
# 5 | f__pymfe.landmarking.linear_discr.median : 0.617
# 6 | f__pymfe.statistical.can_cor.max : 0.622
# 7 | f__pymfe.landmarking.one_nn.mean : 0.622
# 8 | f__pymfe.landmarking.linear_discr.quantiles.1 : 0.622
# 9 | f__pymfe.landmarking.naive_bayes.quantiles.3 : 0.622
# 10 | f__pymfe.landmarking.naive_bayes.median : 0.623
# 11 | f__pymfe.landmarking.one_nn.median : 0.623
# 12 | f__pymfe.landmarking.naive_bayes.mean : 0.624
# 13 | f__pymfe.landmarking.naive_bayes.max : 0.626
# 14 | f__pymfe.model-based.leaves_homo.min : 0.626
# 15 | f__pymfe.statistical.can_cor.quantiles.3 : 0.626
# 16 | f__pymfe.statistical.w_lambda : 0.628
# 17 | f__pymfe.landmarking.one_nn.quantiles.1 : 0.628
# 18 | f__pymfe.landmarking.naive_bayes.quantiles.1 : 0.629
# 19 | f__pymfe.model-based.nodes_per_level.max : 0.631

# %%
from multiprocessing import Pool

feature_pair_losses = []
feature_pairs = list(itertools.combinations(range(len(feature_cols)), 2))


# def f(ind_pair):
#     x_features = x_scaled[:, ind_pair] # x_scaled[:, [i_1, i_2]]
#     clf = cls_func(max_iter=1000).fit(x_features, y)
#     return log_loss(y, clf.predict_proba(x_features))

# print(f"processing {len(feature_pairs)} feature pairs")
# with Pool(2) as p:
#     im = p.imap(f, feature_pairs, chunksize=10)
#     for r in im:
#         feature_pair_losses.append(r)

for i, (i_1, i_2) in enumerate(feature_pairs):
    if  i % 2000 == 0:
        print(f"iteration: {i}")
    x_features = x_scaled[:, [i_1, i_2]]
    clf = cls_func(max_iter=1000).fit(x_features, y)
    feature_pair_losses.append(log_loss(y, clf.predict_proba(x_features)))
# Out:
# iteration: 0
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# iteration: 2000
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# iteration: 4000
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# iteration: 6000
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# iteration: 8000
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# iteration: 10000
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# ...
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# iteration: 362000
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/duncan/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/duncan/research/active_projects/tabzilla/tabzilla_analysis/metafeatures_analysis_baseline_performs_well.ipynb Cell 33 in <cell line: 18>()
#      <a href='vscode-notebook-cell:/Users/duncan/research/active_projects/tabzilla/tabzilla_analysis/metafeatures_analysis_baseline_performs_well.ipynb#Y150sZmlsZQ%3D%3D?line=19'>20</a>     print(f"iteration: {i}")
#      <a href='vscode-notebook-cell:/Users/duncan/research/active_projects/tabzilla/tabzilla_analysis/metafeatures_analysis_baseline_performs_well.ipynb#Y150sZmlsZQ%3D%3D?line=20'>21</a> x_features = x_scaled[:, [i_1, i_2]]
# ---> <a href='vscode-notebook-cell:/Users/duncan/research/active_projects/tabzilla/tabzilla_analysis/metafeatures_analysis_baseline_performs_well.ipynb#Y150sZmlsZQ%3D%3D?line=21'>22</a> clf = cls_func(max_iter=1000).fit(x_features, y)
#      <a href='vscode-notebook-cell:/Users/duncan/research/active_projects/tabzilla/tabzilla_analysis/metafeatures_analysis_baseline_performs_well.ipynb#Y150sZmlsZQ%3D%3D?line=22'>23</a> feature_pair_losses.append(log_loss(y, clf.predict_proba(x_features)))
#
# File ~/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1233, in LogisticRegression.fit(self, X, y, sample_weight)
#    1230 else:
#    1231     n_threads = 1
# -> 1233 fold_coefs_ = Parallel(n_jobs=self.n_jobs, verbose=self.verbose, prefer=prefer)(
#    1234     path_func(
#    1235         X,
#    1236         y,
#    1237         pos_class=class_,
#    1238         Cs=[C_],
#    1239         l1_ratio=self.l1_ratio,
#    1240         fit_intercept=self.fit_intercept,
#    1241         tol=self.tol,
#    1242         verbose=self.verbose,
#    1243         solver=solver,
#    1244         multi_class=multi_class,
#    1245         max_iter=self.max_iter,
#    1246         class_weight=self.class_weight,
#    1247         check_input=False,
#    1248         random_state=self.random_state,
#    1249         coef=warm_start_coef_,
#    1250         penalty=penalty,
#    1251         max_squared_sum=max_squared_sum,
#    1252         sample_weight=sample_weight,
#    1253         n_threads=n_threads,
#    1254     )
#    1255     for class_, warm_start_coef_ in zip(classes_, warm_start_coef)
#    1256 )
#    1258 fold_coefs_, _, n_iter_ = zip(*fold_coefs_)
#    1259 self.n_iter_ = np.asarray(n_iter_, dtype=np.int32)[:, 0]
#
# File ~/miniconda3/envs/sklearn/lib/python3.10/site-packages/joblib/parallel.py:1043, in Parallel.__call__(self, iterable)
#    1034 try:
#    1035     # Only set self._iterating to True if at least a batch
#    1036     # was dispatched. In particular this covers the edge
#    (...)
#    1040     # was very quick and its callback already dispatched all the
#    1041     # remaining jobs.
#    1042     self._iterating = False
# -> 1043     if self.dispatch_one_batch(iterator):
#    1044         self._iterating = self._original_iterator is not None
#    1046     while self.dispatch_one_batch(iterator):
#
# File ~/miniconda3/envs/sklearn/lib/python3.10/site-packages/joblib/parallel.py:861, in Parallel.dispatch_one_batch(self, iterator)
#     859     return False
#     860 else:
# --> 861     self._dispatch(tasks)
#     862     return True
#
# File ~/miniconda3/envs/sklearn/lib/python3.10/site-packages/joblib/parallel.py:779, in Parallel._dispatch(self, batch)
#     777 with self._lock:
#     778     job_idx = len(self._jobs)
# --> 779     job = self._backend.apply_async(batch, callback=cb)
#     780     # A job can complete so quickly than its callback is
#     781     # called before we get here, causing self._jobs to
#     782     # grow. To ensure correct results ordering, .insert is
#     783     # used (rather than .append) in the following line
#     784     self._jobs.insert(job_idx, job)
#
# File ~/miniconda3/envs/sklearn/lib/python3.10/site-packages/joblib/_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File ~/miniconda3/envs/sklearn/lib/python3.10/site-packages/joblib/_parallel_backends.py:572, in ImmediateResult.__init__(self, batch)
#     569 def __init__(self, batch):
#     570     # Don't delay the application, to avoid keeping the input
#     571     # arguments in memory
# --> 572     self.results = batch()
#
# File ~/miniconda3/envs/sklearn/lib/python3.10/site-packages/joblib/parallel.py:262, in BatchedCalls.__call__(self)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File ~/miniconda3/envs/sklearn/lib/python3.10/site-packages/joblib/parallel.py:262, in <listcomp>(.0)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File ~/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/utils/fixes.py:117, in _FuncWrapper.__call__(self, *args, **kwargs)
#     115 def __call__(self, *args, **kwargs):
#     116     with config_context(**self.config):
# --> 117         return self.function(*args, **kwargs)
#
# File ~/miniconda3/envs/sklearn/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:436, in _logistic_regression_path(X, y, pos_class, Cs, fit_intercept, max_iter, tol, verbose, solver, coef, class_weight, dual, penalty, intercept_scaling, multi_class, random_state, check_input, max_squared_sum, sample_weight, l1_ratio, n_threads)
#     432 l2_reg_strength = 1.0 / C
#     433 iprint = [-1, 50, 1, 100, 101][
#     434     np.searchsorted(np.array([0, 1, 2, 3]), verbose)
#     435 ]
# --> 436 opt_res = optimize.minimize(
#     437     func,
#     438     w0,
#     439     method="L-BFGS-B",
#     440     jac=True,
#     441     args=(X, target, sample_weight, l2_reg_strength, n_threads),
#     442     options={"iprint": iprint, "gtol": tol, "maxiter": max_iter},
#     443 )
#     444 n_iter_i = _check_optimize_result(
#     445     solver,
#     446     opt_res,
#     447     max_iter,
#     448     extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
#     449 )
#     450 w0, loss = opt_res.x, opt_res.fun
#
# File ~/miniconda3/envs/sklearn/lib/python3.10/site-packages/scipy/optimize/_minimize.py:696, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     693     res = _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#     694                              **options)
#     695 elif meth == 'l-bfgs-b':
# --> 696     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#     697                            callback=callback, **options)
#     698 elif meth == 'tnc':
#     699     res = _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     700                         **options)
#
# File ~/miniconda3/envs/sklearn/lib/python3.10/site-packages/scipy/optimize/_lbfgsb_py.py:359, in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     353 task_str = task.tobytes()
#     354 if task_str.startswith(b'FG'):
#     355     # The minimization routine wants f and g at the current x.
#     356     # Note that interruptions due to maxfun are postponed
#     357     # until the completion of the current minimization iteration.
#     358     # Overwrite f and g:
# --> 359     f, g = func_and_grad(x)
#     360 elif task_str.startswith(b'NEW_X'):
#     361     # new iteration
#     362     n_iterations += 1
#
# File ~/miniconda3/envs/sklearn/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py:286, in ScalarFunction.fun_and_grad(self, x)
#     284     self._update_x_impl(x)
#     285 self._update_fun()
# --> 286 self._update_grad()
#     287 return self.f, self.g
#
# File ~/miniconda3/envs/sklearn/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py:256, in ScalarFunction._update_grad(self)
#     254 def _update_grad(self):
#     255     if not self.g_updated:
# --> 256         self._update_grad_impl()
#     257         self.g_updated = True
#
# File ~/miniconda3/envs/sklearn/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py:166, in ScalarFunction.__init__.<locals>.update_grad()
#     163         self.ngev += 1
#     164         return np.atleast_1d(grad(np.copy(x), *args))
# --> 166     def update_grad():
#     167         self.g = grad_wrapped(self.x)
#     169 elif grad in FD_METHODS:
#
# KeyboardInterrupt:

# %%
feature_pair_losses
# Out:
# <generator object Pool.imap.<locals>.<genexpr> at 0x1345ec040>

# %%
sorted_inds = np.array(feature_pair_losses).argsort()

for i in range(20):
    ind_pairs = feature_pairs[sorted_inds[i]]
    print(f"{i} | {feature_cols[ind_pairs[0]]} and {feature_cols[ind_pairs[1]]}: {feature_pair_losses[sorted_inds[i]]:.3f}")
# Out:
# array([[0. , 0. ],
#        [0. , 0. ],
#        [0. , 0. ],
#        ...,
#        [0.1, 0.1],
#        [0.2, 0. ],
#        [0.1, 0. ]])

# %%
import multiprocessing
