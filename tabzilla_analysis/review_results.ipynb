# %% [markdown]
# # Review Results
# General notebook for reviewing results files

# %%
import pandas as pd

# %%
df = pd.read_csv("..//TabSurvey/metadataset.csv")

# %%
df.head()
# Out:
#                                  results_bucket_path  \
# 0  results/openml__APSFailure__168868/CatBoost/gp...
# 1  results/openml__APSFailure__168868/CatBoost/gp...
# 2  results/openml__APSFailure__168868/CatBoost/gp...
# 3  results/openml__APSFailure__168868/CatBoost/gp...
# 4  results/openml__APSFailure__168868/CatBoost/gp...
#
#                       dataset_fold_id                dataset_name target_type  \
# 0  openml__APSFailure__168868__fold_0  openml__APSFailure__168868      binary
# 1  openml__APSFailure__168868__fold_0  openml__APSFailure__168868      binary
# 2  openml__APSFailure__168868__fold_0  openml__APSFailure__168868      binary
# 3  openml__APSFailure__168868__fold_0  openml__APSFailure__168868      binary
# 4  openml__APSFailure__168868__fold_0  openml__APSFailure__168868      binary
#
#    alg_name hparam_source  trial_number               alg_hparam_id  \
# 0  CatBoost       default             0   CatBoost__seed_0__trial_0
# 1  CatBoost   random_1_s0             1   CatBoost__seed_0__trial_1
# 2  CatBoost  random_10_s0            10  CatBoost__seed_0__trial_10
# 3  CatBoost  random_11_s0            11  CatBoost__seed_0__trial_11
# 4  CatBoost  random_12_s0            12  CatBoost__seed_0__trial_12
#
#                             exp_name  time__train  ...  AUC__test  \
# 0  gpu-expt-a_091822_065111_fdd9.zip     4.039096  ...   0.994533
# 1  gpu-expt-a_091822_065111_fdd9.zip     3.624039  ...   0.995148
# 2  gpu-expt-a_091822_065111_fdd9.zip     2.494685  ...   0.993307
# 3  gpu-expt-a_091822_065111_fdd9.zip     2.532277  ...   0.989220
# 4  gpu-expt-a_091822_065111_fdd9.zip     4.220030  ...   0.994578
#
#    Accuracy__test  F1__test  time__train-eval  MSE__train  R2__train  \
# 0        0.993421  0.993421          0.185535         NaN        NaN
# 1        0.994605  0.994605          0.129900         NaN        NaN
# 2        0.990921  0.990921          0.074099         NaN        NaN
# 3        0.990132  0.990132          0.061874         NaN        NaN
# 4        0.993684  0.993684          0.121606         NaN        NaN
#
#    MSE__val  R2__val  MSE__test  R2__test
# 0       NaN      NaN        NaN       NaN
# 1       NaN      NaN        NaN       NaN
# 2       NaN      NaN        NaN       NaN
# 3       NaN      NaN        NaN       NaN
# 4       NaN      NaN        NaN       NaN
#
# [5 rows x 31 columns]

# %%
# how many unique datasets?
len(df["dataset_name"].unique())
# Out:
# 191

# %%
# experiment name is exp-name...
df_exp = df.loc[df["exp_name"].str.contains("all-datasets-b"), :]

df_exp.head()
# Out:
#                                      results_bucket_path  \
# 15630  results/openml__Click_prediction_small__190408...
# 15631  results/openml__Click_prediction_small__190408...
# 15632  results/openml__Click_prediction_small__190408...
# 15633  results/openml__Click_prediction_small__190408...
# 15634  results/openml__Click_prediction_small__190408...
#
#                                       dataset_fold_id  \
# 15630  openml__Click_prediction_small__190408__fold_0
# 15631  openml__Click_prediction_small__190408__fold_0
# 15632  openml__Click_prediction_small__190408__fold_0
# 15633  openml__Click_prediction_small__190408__fold_0
# 15634  openml__Click_prediction_small__190408__fold_0
#
#                                  dataset_name target_type      alg_name  \
# 15630  openml__Click_prediction_small__190408      binary  DecisionTree
# 15631  openml__Click_prediction_small__190408      binary  DecisionTree
# 15632  openml__Click_prediction_small__190408      binary  DecisionTree
# 15633  openml__Click_prediction_small__190408      binary  DecisionTree
# 15634  openml__Click_prediction_small__190408      binary  DecisionTree
#
#       hparam_source  trial_number                   alg_hparam_id  \
# 15630       default             0   DecisionTree__seed_0__trial_0
# 15631   random_1_s0             1   DecisionTree__seed_0__trial_1
# 15632  random_10_s0            10  DecisionTree__seed_0__trial_10
# 15633  random_11_s0            11  DecisionTree__seed_0__trial_11
# 15634  random_12_s0            12  DecisionTree__seed_0__trial_12
#
#                                     exp_name  time__train  ...  AUC__test  \
# 15630  all-datasets-b_110322_111059_6ddc.zip     0.433369  ...   0.652457
# 15631  all-datasets-b_110322_111059_6ddc.zip     0.386362  ...   0.643646
# 15632  all-datasets-b_110322_111059_6ddc.zip     1.340713  ...   0.648672
# 15633  all-datasets-b_110322_111059_6ddc.zip     0.275816  ...   0.635343
# 15634  all-datasets-b_110322_111059_6ddc.zip     0.321048  ...   0.635343
#
#        Accuracy__test  F1__test  time__train-eval  MSE__train  R2__train  \
# 15630        0.833542  0.833542          0.037458         NaN        NaN
# 15631        0.832541  0.832541          0.109629         NaN        NaN
# 15632        0.828285  0.828285          0.054828         NaN        NaN
# 15633        0.830788  0.830788          0.069342         NaN        NaN
# 15634        0.830788  0.830788          0.046754         NaN        NaN
#
#        MSE__val  R2__val  MSE__test  R2__test
# 15630       NaN      NaN        NaN       NaN
# 15631       NaN      NaN        NaN       NaN
# 15632       NaN      NaN        NaN       NaN
# 15633       NaN      NaN        NaN       NaN
# 15634       NaN      NaN        NaN       NaN
#
# [5 rows x 31 columns]

# %%
# how many rows for each dataset in these experiments?
df_exp["dataset_name"].value_counts().sort_values()
# Out:
# openml__yeast__145793                      300
# openml__visualizing_environmental__3602    300
# openml__rabe_266__3647                     300
# openml__scene__3485                        300
# openml__socmob__3797                       300
#                                           ...
# openml__lymph__10                          600
# openml__lung-cancer__146024                600
# openml__liver-disorders__52948             600
# openml__musk__3950                         600
# openml__analcatdata_boxing1__3540          600
# Name: dataset_name, Length: 78, dtype: int64

# %%
datasets_b_str ="""openml__acute-inflammations__10089
  openml__ada_agnostic__3896
  openml__aloi__12732
  openml__analcatdata_boxing1__3540
  openml__analcatdata_chlamydia__3739
  openml__anneal__2867
  openml__artificial-characters__14964
  openml__audiology__7
  openml__autos__9
  openml__BNG\(credit-a\)__146047
  openml__bodyfat__5514
  openml__car-evaluation__146192
  openml__cardiotocography__9979
  openml__Census-Income__168340
  openml__chess__3952
  openml__chscase_foot__5012
  openml__cjs__14967
  openml__cleveland__2285
  openml__Click_prediction_small__190408
  openml__colic__25
  openml__colic__27
  openml__collins__3567
  openml__cpu_small__4883
  openml__dataset_sales__190418
  openml__dermatology__35
  openml__EgyptianSkulls__5040
  openml__elevators__3711
  openml__fertility__9984
  openml__fl2000__3566
  openml__fri_c0_100_5__3620
  openml__fri_c3_100_5__3779
  openml__gas-drift__9986
  openml__gina_agnostic__3891
  openml__glass__40
  openml__hayes-roth__146063
  openml__heart-c__48
  openml__heart-h__50
  openml__hepatitis__54
  openml__hill-valley__145847
  openml__ionosphere__145984
  openml__iris__59
  openml__irish__3543
  openml__JapaneseVowels__3510
  openml__kin8nm__2280
  openml__kropt__2076
  openml__labor__4
  openml__ldpa__9974
  openml__LED-display-domain-7digit__125921
  openml__libras__360948
  openml__liver-disorders__52948
  openml__lung-cancer__146024
  openml__lymph__10
  openml__magic__146206
  openml__MagicTelescope__3954
  openml__meta__4729
  openml__monks-problems-2__146065
  openml__mushroom__24
  openml__musk__3950
  openml__nursery__9892
  openml__one-hundred-plants-texture__9956
  openml__page-blocks__30
  openml__pbc__4850
  openml__poker-hand__9890
  openml__pollen__3735
  openml__postoperative-patient-data__146210
  openml__profb__3561
  openml__rabe_266__3647
  openml__Satellite__167211
  openml__scene__3485
  openml__socmob__3797
  openml__solar-flare__2068
  openml__sonar__39
  openml__SpeedDating__146607
  openml__sylva_agnostic__3889
  openml__synthetic_control__3512
  openml__tae__47
  openml__transplant__3748
  openml__visualizing_environmental__3602
  openml__visualizing_livestock__3731
  openml__walking-activity__9945
  openml__Wine__190420
  openml__Wisconsin-breast-cancer-cytology-features__361003
  openml__yeast__145793"""

datasets_b_list = [d.strip() for d in datasets_b_str.split("\n")]

# %%
len(datasets_b_list)
# Out:
# 83

# %%
# get all datasets in datasets_b not in the results...

set(datasets_b_list).difference(df_exp["dataset_name"].unique())
# Out:
# {'openml__BNG\\(credit-a\\)__146047',
#  'openml__Census-Income__168340',
#  'openml__one-hundred-plants-texture__9956',
#  'openml__poker-hand__9890',
#  'openml__walking-activity__9945'}

# %%
# check each...
# df_exp[df_exp["dataset_name"].str.contains("credit-a")]  # no results...
# df_exp[df_exp["dataset_name"].str.contains("Census")]  # no results...
# df_exp[df_exp["dataset_name"].str.contains("hundred")]  # no results...
# df_exp[df_exp["dataset_name"].str.contains("poker")]  # no results...
# df_exp[df_exp["dataset_name"].str.contains("walking")]  # no results...
# Out:
# Empty DataFrame
# Columns: [results_bucket_path, dataset_fold_id, dataset_name, target_type, alg_name, hparam_source, trial_number, alg_hparam_id, exp_name, time__train, Log Loss__train, AUC__train, Accuracy__train, F1__train, time__val, Log Loss__val, AUC__val, Accuracy__val, F1__val, time__test, Log Loss__test, AUC__test, Accuracy__test, F1__test, time__train-eval, MSE__train, R2__train, MSE__val, R2__val, MSE__test, R2__test]
# Index: []
#
# [0 rows x 31 columns]
