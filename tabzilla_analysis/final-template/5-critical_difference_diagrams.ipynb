# %% [markdown]
# # Critical difference diagrams for average performance of each alg
#
# **Notes:**
# - since this uses a pairwise statistical test across algorithms, **we only use datasets where there is a result for every algorithm**
# - here we compare the average performance over all folds of a dataset. ro there is commented-out code in the second cell

# %%
from critical_difference import draw_cd_diagram
import pandas as pd
from pathlib import Path

# make sure that the output folder exists
output_folder = Path("./cd_plots")
output_folder.mkdir(exist_ok=True)

# %% [markdown]
# ## CD plot for accuracy - include all algs

# %%
metric_name = "Accuracy"

# prepare df for CD plot

# uncomment the three lines below to use averaged performance over each dataset, rather than each fold
# agg_metadataset_df = pd.read_csv("./cleaned_results/tuned_aggregated_results.csv")
# metric_col = "Accuracy__test_mean"
# cd_df = agg_metadataset_df.loc[:, ["dataset_name", "alg_name", metric_col]].copy()

# to run this test using average performance over each dataset (rather than each fold), comment out the following three lines and uncomment the three above
fold_metadataset_df = pd.read_csv("./cleaned_results/tuned_fold_results.csv")
metric_col = f"{metric_name}__test"
cd_df = fold_metadataset_df.loc[:, ["dataset_fold_id", "alg_name", metric_col]].copy()

cd_df.columns = ["dataset_name", "classifier_name", "accuracy"]

# drop all datasets where we don't have results for all methods
num_datasets = len(cd_df["dataset_name"].unique())
num_algs = len(cd_df["classifier_name"].unique())

num_algs_per_dataset = cd_df.groupby("dataset_name")["classifier_name"].apply(lambda x: len(set(x)))
incomplete_datasets = list(num_algs_per_dataset[num_algs_per_dataset < num_algs].index)

print(f"total number of datasets: {num_datasets}")
print(f"num. datasets with incomplete results: {len(incomplete_datasets)}")

cd_df = cd_df.loc[~cd_df["dataset_name"].isin(incomplete_datasets), :]

print(f"after removing incomplete datasets, num datasets remaining: {len(cd_df['dataset_name'].unique())}")

# make CD plot
draw_cd_diagram(cd_df, alpha=0.05, fig_filename=f"./cd_plots/{metric_col}.pdf", title=metric_name)
# Out:
# total number of datasets: 1590
# num. datasets with incomplete results: 550
# after removing incomplete datasets, num datasets remaining: 1040
# unique classifiers: ['CatBoost' 'DANet' 'DecisionTree' 'FTTransformer' 'KNN' 'LightGBM'
#  'LinearModel' 'MLP' 'MLP-rtdl' 'NODE' 'RandomForest' 'ResNet' 'SAINT'
#  'STG' 'SVM' 'TabNet' 'VIME' 'XGBoost']
# classifiers tested on nb_max_datasets: ['CatBoost', 'DANet', 'DecisionTree', 'FTTransformer', 'KNN', 'LightGBM', 'LinearModel', 'MLP', 'MLP-rtdl', 'NODE', 'RandomForest', 'ResNet', 'SAINT', 'STG', 'SVM', 'TabNet', 'VIME', 'XGBoost']
# CatBoost         51.0
# DANet            23.0
# DecisionTree     12.0
# FTTransformer    28.0
# KNN              10.0
# LightGBM         66.0
# LinearModel      23.0
# MLP               7.0
# MLP-rtdl          4.0
# NODE             22.0
# RandomForest     27.0
# ResNet           24.0
# SAINT            36.0
# STG              19.0
# SVM              45.0
# TabNet           30.0
# VIME              6.0
# XGBoost          65.0
# dtype: float64
# average ranks: VIME             13.647596
# KNN              12.535577
# LinearModel      11.532212
# MLP              11.192788
# STG              10.775481
# TabNet           10.507692
# DecisionTree     10.483173
# MLP-rtdl          9.956250
# SVM               8.778365
# DANet             8.487500
# NODE              8.467308
# FTTransformer     8.346635
# RandomForest      8.343750
# SAINT             8.308654
# ResNet            7.871154
# LightGBM          7.824519
# XGBoost           7.184135
# CatBoost          6.757212
# dtype: float64
# p-values: ('CatBoost', 'VIME', 1.0967785620831425e-121, True)
# p-values: ('ResNet', 'VIME', 6.882189769708868e-107, True)
# p-values: ('FTTransformer', 'VIME', 2.0294758220042928e-104, True)
# p-values: ('VIME', 'XGBoost', 2.3710223420706458e-104, True)
# p-values: ('NODE', 'VIME', 5.454889120012398e-104, True)
# p-values: ('DANet', 'VIME', 4.574124358321096e-100, True)
# p-values: ('CatBoost', 'KNN', 5.1755833905880295e-99, True)
# p-values: ('LightGBM', 'VIME', 2.763606030766952e-97, True)
# p-values: ('RandomForest', 'VIME', 6.2687963489024425e-93, True)
# p-values: ('SVM', 'VIME', 3.6288386137398906e-92, True)
# p-values: ('SAINT', 'VIME', 4.01003868783364e-85, True)
# p-values: ('KNN', 'ResNet', 1.1917942803475172e-81, True)
# p-values: ('KNN', 'XGBoost', 3.615395424025203e-81, True)
# p-values: ('CatBoost', 'LinearModel', 7.704630382428397e-74, True)
# p-values: ('KNN', 'SVM', 9.015428403465531e-74, True)
# p-values: ('DANet', 'KNN', 1.9828425551121215e-72, True)
# p-values: ('KNN', 'RandomForest', 4.639592179044077e-72, True)
# p-values: ('CatBoost', 'DecisionTree', 6.090841902225862e-72, True)
# p-values: ('KNN', 'NODE', 5.283258758493591e-69, True)
# p-values: ('CatBoost', 'MLP', 1.8842531039678302e-67, True)
# p-values: ('KNN', 'LightGBM', 8.354140946529724e-67, True)
# p-values: ('MLP-rtdl', 'VIME', 1.5026957823034022e-66, True)
# p-values: ('DecisionTree', 'XGBoost', 4.52908879803761e-63, True)
# p-values: ('FTTransformer', 'KNN', 1.9784302647786008e-62, True)
# p-values: ('KNN', 'SAINT', 6.221442492549886e-62, True)
# p-values: ('LinearModel', 'XGBoost', 1.8257911313826743e-56, True)
# p-values: ('CatBoost', 'TabNet', 2.051687151864339e-56, True)
# p-values: ('LinearModel', 'ResNet', 3.027021146337978e-54, True)
# p-values: ('MLP', 'ResNet', 5.078033242100887e-54, True)
# p-values: ('MLP', 'XGBoost', 2.566502746574281e-53, True)
# p-values: ('MLP', 'VIME', 1.1626489950934958e-51, True)
# p-values: ('CatBoost', 'STG', 4.0899560663995917e-50, True)
# p-values: ('FTTransformer', 'MLP', 1.0234177450454007e-48, True)
# p-values: ('DecisionTree', 'VIME', 8.056680240000119e-48, True)
# p-values: ('LinearModel', 'RandomForest', 4.045790676864593e-47, True)
# p-values: ('STG', 'VIME', 1.4754076053001806e-45, True)
# p-values: ('MLP', 'NODE', 1.433988787465498e-44, True)
# p-values: ('TabNet', 'XGBoost', 5.943182723774876e-44, True)
# p-values: ('LinearModel', 'NODE', 1.0900892975246364e-41, True)
# p-values: ('STG', 'XGBoost', 1.451924890933378e-41, True)
# p-values: ('DANet', 'MLP', 2.4292368671381256e-41, True)
# p-values: ('MLP', 'RandomForest', 2.7992541696672904e-41, True)
# p-values: ('ResNet', 'STG', 3.1229100401145597e-40, True)
# p-values: ('DANet', 'LinearModel', 6.46714705760965e-40, True)
# p-values: ('FTTransformer', 'LinearModel', 3.2140387504734556e-39, True)
# p-values: ('LightGBM', 'MLP', 3.5182533925381294e-39, True)
# p-values: ('LightGBM', 'LinearModel', 1.2612443704408976e-38, True)
# p-values: ('TabNet', 'VIME', 5.189771676904267e-36, True)
# p-values: ('LinearModel', 'SAINT', 7.98662471582611e-36, True)
# p-values: ('MLP', 'SAINT', 4.606749119383414e-35, True)
# p-values: ('CatBoost', 'MLP-rtdl', 2.3512565556107382e-34, True)
# p-values: ('DecisionTree', 'LightGBM', 1.702574262236389e-33, True)
# p-values: ('LinearModel', 'SVM', 2.7136281159645615e-33, True)
# p-values: ('LightGBM', 'TabNet', 4.3942181985636595e-33, True)
# p-values: ('SAINT', 'STG', 1.7899106648127502e-31, True)
# p-values: ('MLP', 'SVM', 4.723789057650602e-31, True)
# p-values: ('DecisionTree', 'RandomForest', 2.3823478794677707e-30, True)
# p-values: ('ResNet', 'TabNet', 3.2005183874249953e-29, True)
# p-values: ('NODE', 'STG', 5.133336645257401e-29, True)
# p-values: ('MLP-rtdl', 'ResNet', 1.3581266126425946e-28, True)
# p-values: ('FTTransformer', 'STG', 1.858233368614909e-27, True)
# p-values: ('SAINT', 'TabNet', 9.923135776703991e-27, True)
# p-values: ('MLP-rtdl', 'XGBoost', 3.780944226171803e-26, True)
# p-values: ('DANet', 'STG', 4.574734534186429e-26, True)
# p-values: ('RandomForest', 'STG', 1.1668872903880977e-25, True)
# p-values: ('LightGBM', 'STG', 1.1694802292465614e-25, True)
# p-values: ('FTTransformer', 'TabNet', 3.82261737493389e-25, True)
# p-values: ('DANet', 'TabNet', 8.312048522284174e-25, True)
# p-values: ('DecisionTree', 'KNN', 8.187623287895469e-24, True)
# p-values: ('FTTransformer', 'MLP-rtdl', 1.1345812803745635e-22, True)
# p-values: ('LinearModel', 'VIME', 2.7363998741902744e-22, True)
# p-values: ('RandomForest', 'TabNet', 3.4839783136290344e-22, True)
# p-values: ('KNN', 'MLP-rtdl', 9.287849977426797e-22, True)
# p-values: ('DecisionTree', 'ResNet', 4.3210414869020886e-21, True)
# p-values: ('CatBoost', 'RandomForest', 6.066860869440971e-20, True)
# p-values: ('STG', 'SVM', 8.289634349180536e-20, True)
# p-values: ('KNN', 'STG', 9.25179303278082e-19, True)
# p-values: ('NODE', 'TabNet', 1.6429243340377855e-17, True)
# p-values: ('CatBoost', 'NODE', 2.6533924471213148e-17, True)
# p-values: ('CatBoost', 'DANet', 1.0739358429677209e-16, True)
# p-values: ('MLP-rtdl', 'NODE', 3.5540956889711765e-16, True)
# p-values: ('CatBoost', 'SVM', 3.9629488383409507e-16, True)
# p-values: ('MLP-rtdl', 'SAINT', 4.0030629366068607e-16, True)
# p-values: ('CatBoost', 'FTTransformer', 3.2574153849575995e-15, True)
# p-values: ('SVM', 'TabNet', 7.277621010564091e-15, True)
# p-values: ('DecisionTree', 'SAINT', 1.51799570708867e-14, True)
# p-values: ('LightGBM', 'MLP-rtdl', 1.6611834947734017e-14, True)
# p-values: ('DANet', 'MLP-rtdl', 7.69171880008637e-14, True)
# p-values: ('DANet', 'DecisionTree', 1.1274786062259573e-13, True)
# p-values: ('DecisionTree', 'FTTransformer', 2.296106594209626e-13, True)
# p-values: ('NODE', 'XGBoost', 4.861746831734995e-13, True)
# p-values: ('KNN', 'TabNet', 5.421046748329541e-12, True)
# p-values: ('KNN', 'VIME', 5.467601224007452e-12, True)
# p-values: ('MLP-rtdl', 'RandomForest', 6.5013237086829e-12, True)
# p-values: ('CatBoost', 'SAINT', 1.9077848200335107e-11, True)
# p-values: ('DANet', 'XGBoost', 3.8532409652187875e-11, True)
# p-values: ('RandomForest', 'XGBoost', 8.155495728652932e-11, True)
# p-values: ('SVM', 'XGBoost', 1.7220932759911154e-10, True)
# p-values: ('FTTransformer', 'XGBoost', 5.781153306060828e-10, True)
# p-values: ('KNN', 'MLP', 1.3975753048408797e-09, True)
# p-values: ('MLP', 'MLP-rtdl', 2.343395331359267e-09, True)
# p-values: ('DecisionTree', 'LinearModel', 2.9526576843583245e-09, True)
# p-values: ('DecisionTree', 'NODE', 5.963183846295343e-09, True)
# p-values: ('MLP-rtdl', 'SVM', 6.972939273543292e-09, True)
# p-values: ('CatBoost', 'ResNet', 4.054872970962406e-08, True)
# p-values: ('CatBoost', 'LightGBM', 5.270616329584182e-08, True)
# p-values: ('SAINT', 'XGBoost', 4.921480720705221e-07, True)
# p-values: ('DecisionTree', 'MLP', 1.0061340072973602e-06, True)
# p-values: ('LinearModel', 'MLP-rtdl', 3.5554948702388293e-06, True)
# p-values: ('DecisionTree', 'SVM', 1.3059215542848059e-05, True)
# p-values: ('LinearModel', 'STG', 1.4169321848316621e-05, True)
# p-values: ('SAINT', 'SVM', 2.2673722797788857e-05, True)
# p-values: ('LightGBM', 'NODE', 4.392757908946347e-05, True)
# p-values: ('ResNet', 'SVM', 8.23868432897036e-05, True)
# p-values: ('LightGBM', 'XGBoost', 0.0004910286264537821, True)
# p-values: ('LightGBM', 'SVM', 0.0008445842401444722, True)
# p-values: ('DANet', 'LightGBM', 0.000976829445020697, True)
# p-values: ('DecisionTree', 'STG', 0.0013933773290410792, False)
# p-values: ('ResNet', 'XGBoost', 0.001620066631542372, False)
# p-values: ('DANet', 'ResNet', 0.0018686177337513506, False)
# p-values: ('FTTransformer', 'LightGBM', 0.002361604185899844, False)
# p-values: ('LightGBM', 'RandomForest', 0.0025867859223951423, False)
# p-values: ('RandomForest', 'SVM', 0.0028712148318971766, False)
# p-values: ('NODE', 'SAINT', 0.0040194571194276975, False)
# p-values: ('KNN', 'LinearModel', 0.004439197915350438, False)
# p-values: ('NODE', 'ResNet', 0.005285124307177561, False)
# p-values: ('NODE', 'RandomForest', 0.005536352468317734, False)
# p-values: ('LinearModel', 'TabNet', 0.006699496858557818, False)
# p-values: ('FTTransformer', 'ResNet', 0.009126331331728374, False)
# p-values: ('CatBoost', 'XGBoost', 0.010675435958748397, False)
# p-values: ('MLP-rtdl', 'TabNet', 0.012925713505044043, False)
# p-values: ('MLP', 'STG', 0.01545126038565121, False)
# p-values: ('FTTransformer', 'SAINT', 0.022720316599922546, False)
# p-values: ('LinearModel', 'MLP', 0.02318389604894367, False)
# p-values: ('DANet', 'SVM', 0.024102821724891317, False)
# p-values: ('LightGBM', 'SAINT', 0.02651831278765278, False)
# p-values: ('MLP-rtdl', 'STG', 0.034388666143278845, False)
# p-values: ('MLP', 'TabNet', 0.04964291196961599, False)
# p-values: ('DANet', 'SAINT', 0.05179200409054824, False)
# p-values: ('NODE', 'SVM', 0.10843443774999074, False)
# p-values: ('RandomForest', 'ResNet', 0.10993037615954476, False)
# p-values: ('FTTransformer', 'SVM', 0.12243232989204968, False)
# p-values: ('FTTransformer', 'RandomForest', 0.12272367508427903, False)
# p-values: ('DecisionTree', 'TabNet', 0.12609156633633778, False)
# p-values: ('RandomForest', 'SAINT', 0.21743548467280016, False)
# p-values: ('DecisionTree', 'MLP-rtdl', 0.30563660067095744, False)
# p-values: ('STG', 'TabNet', 0.44351369459252943, False)
# p-values: ('DANet', 'NODE', 0.47320876286580726, False)
# p-values: ('DANet', 'RandomForest', 0.5047571639866084, False)
# p-values: ('FTTransformer', 'NODE', 0.6564159652048296, False)
# p-values: ('ResNet', 'SAINT', 0.7128618633490338, False)
# p-values: ('LightGBM', 'ResNet', 0.740501628450426, False)
# p-values: ('DANet', 'FTTransformer', 0.9144978438848255, False)
# significant diffs: Index(['VIME', 'KNN', 'LinearModel', 'MLP', 'STG', 'TabNet', 'DecisionTree',
#        'MLP-rtdl', 'SVM', 'DANet', 'NODE', 'FTTransformer', 'RandomForest',
#        'SAINT', 'ResNet', 'LightGBM', 'XGBoost', 'CatBoost'],
#       dtype='object')
# [1, 2]
# [2, 3, 5]
# [3, 4, 5]
# [4, 5, 6, 7]
# [11, 12, 9, 10, 8]
# [11, 12, 9, 10, 13, 14]
# [11, 12, 15, 13, 14]
# [16, 17]
# [16, 14]

# %% [markdown]
# ## CD Plot for Log Loss - include all algs

# %%
metric_name = "Log Loss"

# prepare df for CD plot

# uncomment the three lines below to use averaged performance over each dataset, rather than each fold
# agg_metadataset_df = pd.read_csv("./cleaned_results/tuned_aggregated_results.csv")
# metric_col = "Accuracy__test_mean"
# cd_df = agg_metadataset_df.loc[:, ["dataset_name", "alg_name", metric_col]].copy()

# to run this test using average performance over each dataset (rather than each fold), comment out the following three lines and uncomment the three above
fold_metadataset_df = pd.read_csv("./cleaned_results/tuned_fold_results.csv")
metric_col = f"{metric_name}__test"
cd_df = fold_metadataset_df.loc[:, ["dataset_fold_id", "alg_name", metric_col]].copy()

# for log loss - use negative metric
cd_df.loc[:, metric_col] = -1.0 * cd_df[metric_col]

cd_df.columns = ["dataset_name", "classifier_name", "accuracy"]

# drop all datasets where we don't have results for all methods
num_datasets = len(cd_df["dataset_name"].unique())
num_algs = len(cd_df["classifier_name"].unique())

num_algs_per_dataset = cd_df.groupby("dataset_name")["classifier_name"].apply(lambda x: len(set(x)))
incomplete_datasets = list(num_algs_per_dataset[num_algs_per_dataset < num_algs].index)

print(f"total number of datasets: {num_datasets}")
print(f"num. datasets with incomplete results: {len(incomplete_datasets)}")

cd_df = cd_df.loc[~cd_df["dataset_name"].isin(incomplete_datasets), :]

print(f"after removing incomplete datasets, num datasets remaining: {len(cd_df['dataset_name'].unique())}")

# make CD plot
draw_cd_diagram(cd_df, alpha=0.05, fig_filename=f"./cd_plots/{metric_col}.pdf", title=metric_name)
# Out:
# total number of datasets: 1590
# num. datasets with incomplete results: 550
# after removing incomplete datasets, num datasets remaining: 1040
# unique classifiers: ['CatBoost' 'DANet' 'DecisionTree' 'FTTransformer' 'KNN' 'LightGBM'
#  'LinearModel' 'MLP' 'MLP-rtdl' 'NODE' 'RandomForest' 'ResNet' 'SAINT'
#  'STG' 'SVM' 'TabNet' 'VIME' 'XGBoost']
# classifiers tested on nb_max_datasets: ['CatBoost', 'DANet', 'DecisionTree', 'FTTransformer', 'KNN', 'LightGBM', 'LinearModel', 'MLP', 'MLP-rtdl', 'NODE', 'RandomForest', 'ResNet', 'SAINT', 'STG', 'SVM', 'TabNet', 'VIME', 'XGBoost']
# CatBoost         127.0
# DANet             36.0
# DecisionTree     100.0
# FTTransformer     64.0
# KNN               14.0
# LightGBM          78.0
# LinearModel       41.0
# MLP               14.0
# MLP-rtdl          55.0
# NODE              11.0
# RandomForest      38.0
# ResNet            76.0
# SAINT            104.0
# STG               24.0
# SVM               65.0
# TabNet            54.0
# VIME               5.0
# XGBoost          128.0
# dtype: float64
# average ranks: VIME             13.834615
# DecisionTree     13.821154
# KNN              13.298558
# MLP              11.370673
# NODE             11.105769
# MLP-rtdl         10.468269
# TabNet           10.361058
# LinearModel       9.758654
# STG               9.404808
# DANet             8.680769
# RandomForest      8.505288
# FTTransformer     8.248077
# SVM               8.069231
# LightGBM          7.901923
# ResNet            7.779808
# SAINT             6.466346
# XGBoost           6.464423
# CatBoost          5.460577
# dtype: float64
# p-values: ('CatBoost', 'VIME', 2.0333444909355802e-154, True)
# p-values: ('CatBoost', 'DecisionTree', 2.0230527482604447e-148, True)
# p-values: ('VIME', 'XGBoost', 3.867512023728674e-142, True)
# p-values: ('CatBoost', 'KNN', 7.743143348915749e-140, True)
# p-values: ('DecisionTree', 'SAINT', 3.406957772954383e-139, True)
# p-values: ('DecisionTree', 'XGBoost', 1.935367842897742e-138, True)
# p-values: ('SVM', 'VIME', 1.394788912118103e-137, True)
# p-values: ('CatBoost', 'NODE', 9.617696835757877e-134, True)
# p-values: ('KNN', 'SVM', 3.783063310811371e-129, True)
# p-values: ('KNN', 'XGBoost', 1.3972942841605934e-126, True)
# p-values: ('SAINT', 'VIME', 5.217776339753259e-124, True)
# p-values: ('DecisionTree', 'RandomForest', 2.6075419894113114e-120, True)
# p-values: ('DecisionTree', 'SVM', 3.9034250007617715e-118, True)
# p-values: ('KNN', 'SAINT', 4.1042757611778885e-118, True)
# p-values: ('NODE', 'XGBoost', 8.542041539872582e-118, True)
# p-values: ('DecisionTree', 'FTTransformer', 1.6974354164132463e-117, True)
# p-values: ('DANet', 'DecisionTree', 5.085939584684801e-117, True)
# p-values: ('DecisionTree', 'ResNet', 7.489194422919759e-114, True)
# p-values: ('DecisionTree', 'STG', 6.642513963456342e-110, True)
# p-values: ('CatBoost', 'MLP', 2.763015323235725e-107, True)
# p-values: ('DecisionTree', 'LinearModel', 8.815118620818736e-103, True)
# p-values: ('DecisionTree', 'NODE', 4.2718564888090985e-102, True)
# p-values: ('ResNet', 'VIME', 4.709941608056383e-102, True)
# p-values: ('DecisionTree', 'LightGBM', 9.915696476631399e-101, True)
# p-values: ('STG', 'VIME', 1.6280108055590385e-97, True)
# p-values: ('LinearModel', 'VIME', 7.391663780450454e-95, True)
# p-values: ('KNN', 'STG', 2.432595762412488e-94, True)
# p-values: ('KNN', 'RandomForest', 2.1548483716789094e-90, True)
# p-values: ('DANet', 'VIME', 3.75168153036339e-90, True)
# p-values: ('NODE', 'SAINT', 6.119265527206477e-90, True)
# p-values: ('CatBoost', 'LinearModel', 3.5245175487169727e-88, True)
# p-values: ('RandomForest', 'VIME', 4.712526086409657e-87, True)
# p-values: ('MLP', 'XGBoost', 2.131909826713421e-86, True)
# p-values: ('MLP', 'SAINT', 6.045750986174045e-86, True)
# p-values: ('DANet', 'KNN', 6.757488089466278e-85, True)
# p-values: ('FTTransformer', 'VIME', 1.7305475122310512e-84, True)
# p-values: ('CatBoost', 'TabNet', 3.68956393108721e-84, True)
# p-values: ('KNN', 'ResNet', 6.020498024666243e-81, True)
# p-values: ('KNN', 'LinearModel', 2.805175821170544e-80, True)
# p-values: ('CatBoost', 'RandomForest', 4.2532325079635857e-78, True)
# p-values: ('CatBoost', 'MLP-rtdl', 2.0287451048611705e-76, True)
# p-values: ('TabNet', 'XGBoost', 1.48937812413033e-75, True)
# p-values: ('LightGBM', 'VIME', 7.414368594101664e-75, True)
# p-values: ('NODE', 'VIME', 3.2058258677060176e-71, True)
# p-values: ('MLP', 'ResNet', 5.7116475422124315e-70, True)
# p-values: ('SAINT', 'TabNet', 3.6970912995502757e-68, True)
# p-values: ('MLP-rtdl', 'SAINT', 3.463335573902392e-67, True)
# p-values: ('KNN', 'LightGBM', 2.485303618223273e-65, True)
# p-values: ('FTTransformer', 'KNN', 6.225378761881311e-64, True)
# p-values: ('MLP', 'SVM', 6.269067796035427e-64, True)
# p-values: ('LinearModel', 'XGBoost', 2.4115134381510723e-62, True)
# p-values: ('FTTransformer', 'MLP', 7.239126352810976e-61, True)
# p-values: ('MLP-rtdl', 'XGBoost', 1.2101717963740688e-58, True)
# p-values: ('MLP-rtdl', 'ResNet', 9.52157132676577e-58, True)
# p-values: ('NODE', 'SVM', 1.1484913163545469e-57, True)
# p-values: ('FTTransformer', 'MLP-rtdl', 2.856785420821509e-56, True)
# p-values: ('LinearModel', 'SAINT', 2.415364876742763e-50, True)
# p-values: ('SAINT', 'STG', 7.62405741868811e-50, True)
# p-values: ('KNN', 'NODE', 1.6999643911012168e-49, True)
# p-values: ('DecisionTree', 'MLP', 8.065923188750336e-49, True)
# p-values: ('CatBoost', 'STG', 2.5385850206756797e-48, True)
# p-values: ('NODE', 'RandomForest', 4.245914552372995e-48, True)
# p-values: ('MLP', 'RandomForest', 6.889593945470616e-45, True)
# p-values: ('CatBoost', 'FTTransformer', 1.194671500622677e-44, True)
# p-values: ('CatBoost', 'DANet', 2.240155715581625e-44, True)
# p-values: ('RandomForest', 'XGBoost', 8.353998929252546e-44, True)
# p-values: ('DecisionTree', 'KNN', 2.0067523906490214e-43, True)
# p-values: ('DANet', 'MLP', 1.5583851802693296e-41, True)
# p-values: ('DecisionTree', 'MLP-rtdl', 7.372274170383724e-41, True)
# p-values: ('STG', 'XGBoost', 1.0004956083327018e-40, True)
# p-values: ('LinearModel', 'SVM', 2.6274333528061795e-37, True)
# p-values: ('DANet', 'XGBoost', 2.822318700255008e-37, True)
# p-values: ('LinearModel', 'MLP', 4.136979848192902e-37, True)
# p-values: ('MLP', 'STG', 5.076890400501189e-37, True)
# p-values: ('DecisionTree', 'TabNet', 4.703324040429387e-36, True)
# p-values: ('MLP-rtdl', 'SVM', 5.952262958614843e-36, True)
# p-values: ('ResNet', 'TabNet', 1.0742847949843537e-35, True)
# p-values: ('LightGBM', 'TabNet', 1.0954467276569396e-34, True)
# p-values: ('SVM', 'TabNet', 3.0926385962716424e-34, True)
# p-values: ('LightGBM', 'NODE', 2.1358804633426154e-32, True)
# p-values: ('LightGBM', 'MLP', 1.4650653526838282e-31, True)
# p-values: ('CatBoost', 'ResNet', 1.046873229095006e-30, True)
# p-values: ('DANet', 'SAINT', 3.0744486766093692e-30, True)
# p-values: ('FTTransformer', 'XGBoost', 9.186638215062101e-30, True)
# p-values: ('FTTransformer', 'SAINT', 3.3169723505699945e-28, True)
# p-values: ('CatBoost', 'LightGBM', 7.479970053868216e-28, True)
# p-values: ('DANet', 'NODE', 1.9631412144577078e-27, True)
# p-values: ('DANet', 'MLP-rtdl', 2.1007358889231144e-27, True)
# p-values: ('NODE', 'STG', 2.9228154379245026e-27, True)
# p-values: ('CatBoost', 'SVM', 4.2542328184292754e-27, True)
# p-values: ('DecisionTree', 'VIME', 2.0779170034977646e-26, True)
# p-values: ('DANet', 'TabNet', 2.0667360469819343e-25, True)
# p-values: ('MLP-rtdl', 'RandomForest', 4.21105884966491e-24, True)
# p-values: ('LightGBM', 'MLP-rtdl', 1.5224294598209707e-22, True)
# p-values: ('NODE', 'ResNet', 2.883916763107033e-21, True)
# p-values: ('STG', 'TabNet', 5.776975411446621e-21, True)
# p-values: ('MLP', 'VIME', 1.7954253361549904e-20, True)
# p-values: ('ResNet', 'XGBoost', 1.477953484894622e-19, True)
# p-values: ('FTTransformer', 'TabNet', 2.7795018324858624e-19, True)
# p-values: ('ResNet', 'SAINT', 2.9101648970551273e-19, True)
# p-values: ('RandomForest', 'SAINT', 3.280814966794166e-19, True)
# p-values: ('MLP-rtdl', 'STG', 3.3054702950977597e-19, True)
# p-values: ('LinearModel', 'MLP-rtdl', 4.626614269186084e-18, True)
# p-values: ('LightGBM', 'XGBoost', 4.876047802034625e-18, True)
# p-values: ('SAINT', 'SVM', 3.593546451157206e-17, True)
# p-values: ('RandomForest', 'TabNet', 9.216760117106446e-16, True)
# p-values: ('LightGBM', 'LinearModel', 2.079914032336602e-14, True)
# p-values: ('STG', 'SVM', 3.067767881610367e-14, True)
# p-values: ('LinearModel', 'RandomForest', 1.3848188168148153e-13, True)
# p-values: ('MLP', 'NODE', 1.65919093887335e-13, True)
# p-values: ('SVM', 'XGBoost', 4.083444970795613e-13, True)
# p-values: ('LinearModel', 'STG', 1.212926107656537e-10, True)
# p-values: ('LinearModel', 'ResNet', 2.463861892504488e-10, True)
# p-values: ('FTTransformer', 'SVM', 5.249230924305602e-10, True)
# p-values: ('DANet', 'LinearModel', 1.822469082455868e-09, True)
# p-values: ('CatBoost', 'SAINT', 1.6935250848798074e-08, True)
# p-values: ('LightGBM', 'SAINT', 2.0371602258409858e-08, True)
# p-values: ('KNN', 'TabNet', 5.920780236922755e-08, True)
# p-values: ('MLP-rtdl', 'VIME', 7.608334262621133e-08, True)
# p-values: ('LinearModel', 'TabNet', 1.8664009925272162e-07, True)
# p-values: ('FTTransformer', 'NODE', 6.57729904133561e-07, True)
# p-values: ('LightGBM', 'RandomForest', 2.0582443041674057e-06, True)
# p-values: ('MLP-rtdl', 'NODE', 2.555489282229118e-06, True)
# p-values: ('DANet', 'SVM', 6.093031617641432e-06, True)
# p-values: ('LinearModel', 'NODE', 1.6882644304055724e-05, True)
# p-values: ('FTTransformer', 'LightGBM', 6.486286933924393e-05, True)
# p-values: ('KNN', 'MLP', 8.920776144480126e-05, True)
# p-values: ('TabNet', 'VIME', 0.0003907708951319118, True)
# p-values: ('CatBoost', 'XGBoost', 0.0004609520337044478, True)
# p-values: ('RandomForest', 'SVM', 0.0006600296951188845, True)
# p-values: ('LightGBM', 'STG', 0.000840520353781724, True)
# p-values: ('KNN', 'MLP-rtdl', 0.0009251158110731674, True)
# p-values: ('FTTransformer', 'ResNet', 0.001506975932315705, True)
# p-values: ('DANet', 'LightGBM', 0.002045516053373227, True)
# p-values: ('NODE', 'TabNet', 0.0053723317252801295, False)
# p-values: ('DANet', 'FTTransformer', 0.011288697857525917, False)
# p-values: ('ResNet', 'SVM', 0.01283098819077905, False)
# p-values: ('DANet', 'ResNet', 0.06157214108408476, False)
# p-values: ('SAINT', 'XGBoost', 0.08268896030081593, False)
# p-values: ('RandomForest', 'ResNet', 0.10516456160054478, False)
# p-values: ('ResNet', 'STG', 0.12550526332622464, False)
# p-values: ('FTTransformer', 'RandomForest', 0.14450941919075078, False)
# p-values: ('FTTransformer', 'STG', 0.200172755566971, False)
# p-values: ('LightGBM', 'SVM', 0.28924726600315953, False)
# p-values: ('KNN', 'VIME', 0.3203093924021634, False)
# p-values: ('MLP', 'TabNet', 0.3454481502240363, False)
# p-values: ('DANet', 'RandomForest', 0.37347036924463983, False)
# p-values: ('FTTransformer', 'LinearModel', 0.40699115821767273, False)
# p-values: ('RandomForest', 'STG', 0.44796622372130834, False)
# p-values: ('DANet', 'STG', 0.4662021541741831, False)
# p-values: ('LightGBM', 'ResNet', 0.6216921429679163, False)
# p-values: ('MLP', 'MLP-rtdl', 0.8151606221868777, False)
# p-values: ('MLP-rtdl', 'TabNet', 0.953621494739308, False)
# significant diffs: Index(['VIME', 'DecisionTree', 'KNN', 'MLP', 'NODE', 'MLP-rtdl', 'TabNet',
#        'LinearModel', 'STG', 'DANet', 'RandomForest', 'FTTransformer', 'SVM',
#        'LightGBM', 'ResNet', 'SAINT', 'XGBoost', 'CatBoost'],
#       dtype='object')
# [0, 2]
# [3, 5, 6]
# [4, 6]
# [7, 11]
# [11, 8, 9, 10]
# [14, 8, 9, 10]
# [14, 12, 13]
# [15, 16]

# %% [markdown]
# ## TBD: CD Plot comparing best alg in each class by log loss, using all datasets

# %%
## CD Plot for Log Loss - include all algs
metric_name = "Log Loss"

# prepare df for CD plot

# uncomment the three lines below to use averaged performance over each dataset, rather than each fold
# agg_metadataset_df = pd.read_csv("./cleaned_results/tuned_aggregated_results.csv")
# metric_col = "Accuracy__test_mean"
# cd_df = agg_metadataset_df.loc[:, ["dataset_name", "alg_name", metric_col]].copy()

# to run this test using average performance over each dataset (rather than each fold), comment out the following three lines and uncomment the three above
fold_metadataset_df = pd.read_csv("./cleaned_results/tuned_fold_results.csv")
metric_col = f"{metric_name}__test"


# cd_df = fold_metadataset_df.loc[:, ["dataset_fold_id", "alg_name", metric_col]].copy()

# # for log loss - use negative metric
# cd_df.loc[:, metric_col] = -1.0 * cd_df[metric_col]

# cd_df.columns = ["dataset_name", "classifier_name", "accuracy"]

# # drop all datasets where we don't have results for all methods
# num_datasets = len(cd_df["dataset_name"].unique())
# num_algs = len(cd_df["classifier_name"].unique())

# num_algs_per_dataset = cd_df.groupby("dataset_name")["classifier_name"].apply(lambda x: len(set(x)))
# incomplete_datasets = list(num_algs_per_dataset[num_algs_per_dataset < num_algs].index)

# print(f"total number of datasets: {num_datasets}")
# print(f"num. datasets with incomplete results: {len(incomplete_datasets)}")

# cd_df = cd_df.loc[~cd_df["dataset_name"].isin(incomplete_datasets), :]

# print(f"after removing incomplete datasets, num datasets remaining: {len(cd_df['dataset_name'].unique())}")

# # make CD plot
# draw_cd_diagram(cd_df, alpha=0.05, fig_filename=f"./cd_plots/{metric_col}.pdf", title=metric_name)

# %% [markdown]
# # TODO: create plots for subsets of algs
# # TODO: create plots comparing best perfomrance for each class of algs (trees, neural, baselines)
